# %%
from ultralytics import YOLO
import cv2
# Load an official or custom modelqj
# model = YOLO('yolov8x.pt')  # Load an official Detect model
# model = YOLO('yolov8n-seg.pt')  # Load an official Segment model
model2 = YOLO('checkpoints/yolov8x-pose-p6.pt')  # Load an official Pose model
# model = YOLO('path/to/best.pt')  # Load a custom trained model

# Perform tracking with the model
# results = model.track(source="datasets/IMG_1044.mov" ,stream=False,show=True)
results2 = model2.track(source="rtsp://dudnjs:aiffelmodu@192.168.219.102:554/stream1" ,stream=True,show=False)
# Tracking with default tracker
for r in results2:
    keypoints = r.keypoints
    # masks = r.masks  # Masks object for segment masks outputs
    probs = r.probs  # Class probabilities for classification outputs
    print(keypoints)
    # print(masks)
    print(probs)
    res_plotted = r.plot()
    print(res_plotted)
    cv2.imshow(f"Tracking_Stream", res_plotted)

    key = cv2.waitKey(1)
    if key == ord('q'):
        break
# print(type(results2[0]))
# results = model.track(source="Sample/01.원천데이터/02.구매행동/02.선택/C_2_2_10_BU_SYA_09-17_16-18-31_CA_RGB_DF1_F1_F1.mp4", show=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker

# %%
import cv2

def get_video_fps(video_path):
    # 비디오 파일 열기
    cap = cv2.VideoCapture(video_path)
    
    # 비디오 파일이 열렸는지 확인
    if not cap.isOpened():
        print("비디오 파일을 열 수 없습니다.")
        return None
    
    # FPS 가져오기
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    # 비디오 파일 닫기
    cap.release()
    
    return fps

# 비디오 파일 경로
video_path = 'C_3_12_1_BU_SMC_08-07_13-30-11_CC_RGB_DF2_M1.mp4'

# FPS 가져오기
fps = get_video_fps(video_path)

if fps is not None:
    print("비디오의 FPS는 {}입니다.".format(fps))
# Out:
# 비디오의 FPS는 3.0입니다.

# %%
import cv2

# 비디오 파일 경로
video_path = 'Sample_buying/Sample/01.원천데이터/02.구매행동/02.선택/C_2_2_10_BU_SYA_09-17_16-18-31_CA_RGB_DF1_F1_F1.mp4'

# 비디오 파일 열기
cap = cv2.VideoCapture(video_path)

# 누적 프레임 번호 변수
frame_number = 179
#마지막 1443
#1443-1080= 363
# 프레임 읽기
ret, frame = cap.read()

# 초기화
current_frame_number = cap.get(cv2.CAP_PROP_POS_FRAMES)  # 현재 프레임 번호
frame_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000  # 현재 프레임의 시간(초)

# 반복
while True:

    # 프레임 정보 표시
    cv2.putText(frame, f"Frame: {current_frame_number}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 2)
    cv2.putText(frame, f"Time: {frame_time:.2f} seconds", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 2)

    # 프레임 보여주기
    cv2.imshow('Frame', frame)

    # 키 입력 처리
    key = cv2.waitKey(1) & 0xFF

    # 왼쪽 화살표 키: 이전 프레임으로 이동
    if key == ord('a'):
        frame_number -= 1
        if frame_number < 0:
            frame_number = 0

    # 오른쪽 화살표 키: 다음 프레임으로 이동
    elif key == ord('d'):
        frame_number += 1

    # 'q' 키: 종료
    elif key == ord('q'):
        break

    # 프레임 설정 및 읽기
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
    ret, frame = cap.read()

    # 프레임 정보 업데이트
    current_frame_number = cap.get(cv2.CAP_PROP_POS_FRAMES)  # 현재 프레임 번호
    frame_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000  # 현재 프레임의 시간(초)

# 비디오 해제
cap.release()

# 종료 메시지
print("종료되었습니다.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 48
#      45     break
#      47 # 프레임 설정 및 읽기
# ---> 48 cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
#      49 ret, frame = cap.read()
#      51 # 프레임 정보 업데이트
#
# KeyboardInterrupt:

# %%
import xmltodict
import json

def convert_xml_to_json(xml_file_path, json_file_path):
    # XML 파일을 열고 읽기
    with open(xml_file_path, 'r', encoding='utf-8') as file:
        xml_string = file.read()
    
    # XML 문자열을 파이썬 딕셔너리로 변환
    dict_data = xmltodict.parse(xml_string)
    
    # 딕셔너리를 JSON 파일로 저장
    with open(json_file_path, 'w', encoding='utf-8') as json_file:
        json_file.write(json.dumps(dict_data, indent=4))

# 사용 예제
xml_file_path = 'Sample_buying/Sample/02.라벨링데이터/02.구매행동/02.선택/C_2_2_10_BU_SYA_09-17_16-18-31_CA_RGB_DF1_F1_F1.xml'
# XML 파일을 열고 읽기
with open(xml_file_path, 'r', encoding='utf-8') as file:
    xml_string = file.read()

# XML 문자열을 파이썬 딕셔너리로 변환
dict_data = xmltodict.parse(xml_string)
print(len(dict_data['annotations']['meta']['task']['labels']['label']))

for i in dict_data['annotations']['meta']['task']['labels']['label']:
    print(i["name"])
print(dict_data['annotations']['track'][0].keys())
print(dict_data['annotations']['track'][0]["box"])
print(dict_data['annotations']['track'][0]['@label'])
print(len(dict_data['annotations']['track'][0]['box']))
print(dict_data['annotations']['track'][0]['box'][0].keys())
# Out:
# 33
# Pelvis
# Center head
# return_start
# return_end
# compare_start
# moving
# compare_end
# Left hip
# Left knee
# Left foot
# Right  hip
# Right knee
# Right foot
# Spine naval
# Spine chest
# Neck base
# Right shoulder
# Right elbow
# Right hand
# Left shoulder
# Left elbow
# Left hand
# select_start
# select_end
# test_start
# test_end
# buying_start
# buying_end
# object_snack
# object_drink
# object_groceries
# object_daily necessity
# object_pay
# dict_keys(['@id', '@label', '@source', 'box'])
# ...

# %%
import os
def create_directory_recursively(path):
    try:
        # exist_ok=True 옵션은 해당 경로의 폴더가 이미 존재해도 에러를 발생시키지 않음
        os.makedirs(path, exist_ok=True)
        print(f"'{path}' 디렉토리가 생성되었거나 이미 존재합니다.")
    except PermissionError:
        # 권한 오류 처리
        print(f"권한 오류: '{path}' 디렉토리를 생성할 수 없습니다. 접근 권한을 확인하세요.")
    except Exception as e:
        # 기타 오류 처리
        print(f"오류 발생: {e}")
def cut_video(video_path, new_path,data_root_path ,start_frame,end_frame):
    new_video_path=video_path.replace(data_root_path, new_path)
    
    output_path = f'{new_video_path[:-4]}_{start_frame}_{end_frame}.mp4'
    if(os.path.exists(output_path)):
        print("이미 컷편집을 완료했습니다.")
        print("*************")
        return
    # 비디오 캡처 객체 생성
    cap = cv2.VideoCapture(video_path)

    # 총 프레임 수와 FPS 확인
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    # 출력 비디오 설정 (코덱, FPS, 해상도)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    frame_width = int(cap.get(3))
    frame_height = int(cap.get(4))
    new_video_path=video_path.replace(data_root_path, new_path)

    new_video_dir = os.path.dirname(new_video_path)
    # Create the directory if it doesn't exist
    create_directory_recursively(new_video_dir)
    print(output_path)
    
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    current_frame = 0
    while(cap.isOpened()):
        ret, frame = cap.read()
        
        if ret:
            if start_frame <= current_frame <= end_frame:
                out.write(frame)
            
            if current_frame > end_frame:
                break
            
            current_frame += 1
        else:
            break

    # 모든 작업 완료 후 해제
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print("완료")
    print("*************")

# %% [markdown]
# # 컷편집 기능

# %%
import os



def count_mp4_files(path,end):
  """
  주어진 경로와 하위 폴더들을 재귀적으로 탐색하여 mp4 파일 개수를 센다.

  Args:
    path: 탐색을 시작할 경로

  Returns:
    mp4 파일 개수
  """
  mp4_files = []
  mp4_count = 0
  def _count_mp4_files_in_dir(dir_path):
    nonlocal mp4_count
    nonlocal mp4_files
    for file in os.listdir(dir_path):
      full_path = os.path.join(dir_path, file)
      if os.path.isfile(full_path):
        if file.endswith(f".{end}"):
          mp4_count += 1
          mp4_files.append(full_path)
      elif os.path.isdir(full_path):
        _count_mp4_files_in_dir(full_path)

  _count_mp4_files_in_dir(path)

  return mp4_count, mp4_files
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_04.구매_1"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_04.구매"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_04.구매_2"
mp4_count_12, mp4_files = count_mp4_files(path_origin,"mp4")
print(f"총 mp4 파일 개수: {mp4_count_12+mp4_count_1}")




path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_03.시험_1"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_03.시험"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_03.시험_2"
mp4_count_12, mp4_files = count_mp4_files(path_origin,"mp4")
print(f"총 mp4 파일 개수: {mp4_count_12+mp4_count_1}")


path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_02.선택_1"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_02.선택"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_02.선택_2"
mp4_count_12, mp4_files = count_mp4_files(path_origin,"mp4")
print(f"총 mp4 파일 개수: {mp4_count_12+mp4_count_1}")



path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_01.매장이동_01.매장이동_1"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_01.매장이동_01.매장이동"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_01.매장이동_01.매장이동_2"
mp4_count_12, mp4_files = count_mp4_files(path_origin,"mp4")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_01.매장이동_01.매장이동_3"
mp4_count_3, mp4_files = count_mp4_files(path_origin,"mp4")

print(f"총 mp4 파일 개수: {mp4_count_12+mp4_count_1+ mp4_count_3}")

# 예시 코드
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_2"
mp4_count_12, mp4_files = count_mp4_files(path_origin,"mp4")
print(f"총 mp4 파일 개수: {mp4_count_12+mp4_count_1}")



path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_04.구매_1"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_04.구매"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_04.구매_2"
mp4_count_12, mp4_files = count_mp4_files(path_origin,"mp4")
print(f"총 mp4 파일 개수: {mp4_count_12+mp4_count_1}")


path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_03.시험_1"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_03.시험"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_03.시험_2"
mp4_count_12, mp4_files = count_mp4_files(path_origin,"mp4")
print(f"총 mp4 파일 개수: {mp4_count_12+mp4_count_1}")


path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_02.선택_1"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_02.선택"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_02.선택_2"
mp4_count_12, mp4_files = count_mp4_files(path_origin,"mp4")
print(f"총 mp4 파일 개수: {mp4_count_12+mp4_count_1}")



path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_01.매장이동_01.매장이동_1"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_01.매장이동_01.매장이동"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_01.매장이동_01.매장이동_2"
mp4_count_12, mp4_files = count_mp4_files(path_origin,"mp4")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_01.매장이동_01.매장이동_3"
mp4_count_3, mp4_files = count_mp4_files(path_origin,"mp4")

print(f"총 mp4 파일 개수: {mp4_count_12+mp4_count_1+ mp4_count_3}")

# 예시 코드
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_2"
mp4_count_12, mp4_files = count_mp4_files(path_origin,"mp4")
print(f"총 mp4 파일 개수: {mp4_count_12+mp4_count_1}")

# path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_01.매장이동_01.매장이동"
# path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_01.매장이동_01.매장이동"
# mp4_count, mp4_files = count_mp4_files(path_origin,"mp4")
# xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
# print(f"총 mp4 파일 개수: {mp4_count}")
# print(f"총 xml 파일 개수: {xml_count}")
# print(f"총 pkl 파일 개수: {pkl_count}")
# path = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess"
# pathpkl = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcessToPkl"
# mp4_count, mp4_files = count_mp4_files(path,"mp4")
# pkl_count, pkl_files = count_mp4_files(pathpkl,"pkl")


print(f"mp4 파일 목록: {mp4_files}")
print(f"mp4 파일 목록: {len(mp4_files)}")
print(f"mp4 파일 목록: {mp4_files[0]}")
# print(f"mp4 파일 목록: {pkl_files[0]}")
# print(f"mp4 파일 목록: {xml_files[0]}")
# Out:
# 총 xml 파일 개수: 804
# 총 mp4 파일 개수: 804
# 총 xml 파일 개수: 800
# 총 mp4 파일 개수: 800
# 총 xml 파일 개수: 942
# 총 mp4 파일 개수: 942
# 총 xml 파일 개수: 809
# 총 mp4 파일 개수: 809
# 총 xml 파일 개수: 804
# 총 mp4 파일 개수: 804
# 총 xml 파일 개수: 804
# 총 mp4 파일 개수: 804
# 총 xml 파일 개수: 800
# 총 mp4 파일 개수: 800
# 총 xml 파일 개수: 942
# 총 mp4 파일 개수: 942
# 총 xml 파일 개수: 809
# 총 mp4 파일 개수: 809
# 총 xml 파일 개수: 804
# 총 mp4 파일 개수: 804
# ...

# %%
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_03.시험"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_03.시험"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")

print(f"총 mp4 파일 개수: {mp4_count_1}")


path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_02.선택"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_02.선택"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")

print(f"총 mp4 파일 개수: {mp4_count_1}")



path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_01.매장이동_01.매장이동"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_01.매장이동_01.매장이동"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")

print(f"총 mp4 파일 개수: {mp4_count_1}")

# 예시 코드
path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_05.반품"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")

print(f"총 mp4 파일 개수: {mp4_count_1}")



path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매"
path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매"
mp4_count_1, mp4_files = count_mp4_files(path_origin,"mp4")
xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
print(f"총 xml 파일 개수: {xml_count}")

print(f"총 mp4 파일 개수: {mp4_count_1}")





# path_origin = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_01.매장이동_01.매장이동"
# path_origin_label = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_01.매장이동_01.매장이동"
# mp4_count, mp4_files = count_mp4_files(path_origin,"mp4")
# xml_count, xml_files = count_mp4_files(path_origin_label,"xml")
# print(f"총 mp4 파일 개수: {mp4_count}")
# print(f"총 xml 파일 개수: {xml_count}")
# print(f"총 pkl 파일 개수: {pkl_count}")
# path = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess"
# pathpkl = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcessToPkl"
# mp4_count, mp4_files = count_mp4_files(path,"mp4")
# pkl_count, pkl_files = count_mp4_files(pathpkl,"pkl")


print(f"mp4 파일 목록: {mp4_files}")
print(f"mp4 파일 목록: {len(mp4_files)}")
print(f"mp4 파일 목록: {mp4_files[0]}")
# print(f"mp4 파일 목록: {pkl_files[0]}")
# print(f"mp4 파일 목록: {xml_files[0]}")
# Out:
# 총 xml 파일 개수: 100
# 총 mp4 파일 개수: 100
# 총 xml 파일 개수: 118
# 총 mp4 파일 개수: 118
# 총 xml 파일 개수: 101
# 총 mp4 파일 개수: 101
# 총 xml 파일 개수: 101
# 총 mp4 파일 개수: 101
# 총 xml 파일 개수: 100
# 총 mp4 파일 개수: 100
# ...

# %%
# 영상 파일 경로

for idx, j in enumerate(mp4_files):
    data_root_path= "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터"
    new_path= "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess"
    # XML 파일을 열고 읽기
    print("------")
    print(idx)

    if "매장이동" in j:
        continue
    path_parts = j.split('/')
    print(path_parts[-1])
    filtered_items = [item for item in xml_files if path_parts[-1][:-3] in item]
    print(filtered_items[0])

    action_list= [
"select_start","select_end",
  "test_start", "test_end",
  "buying_start", "buying_end",
  "return_start", "return_end",
  "compare_start", "compare_end"
]
    start_q = []
    end_q = []
    print(j)
    with open(filtered_items[0], 'r', encoding='utf-8') as file:
        xml_string = file.read()
    # XML 문자열을 파이썬 딕셔너리로 변환
    dict_data = xmltodict.parse(xml_string)
    for i in range(len(dict_data['annotations']['track'])):
        if dict_data['annotations']['track'][i]['@label'] in action_list:
            print(dict_data['annotations']['track'][i]['@label'])
            if(isinstance(dict_data['annotations']['track'][i]["box"], list)):
                print(dict_data['annotations']['track'][i]["box"][0]["@frame"])
                if "start" in dict_data['annotations']['track'][i]['@label'] :
                    start_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
                if "end" in dict_data['annotations']['track'][i]['@label'] :
                    end_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
            else:
                print(dict_data['annotations']['track'][i]["box"]["@frame"])
                if "start" in dict_data['annotations']['track'][i]['@label'] :
                    start_q.append(int(dict_data['annotations']['track'][i]["box"]["@frame"]))
                if "end" in dict_data['annotations']['track'][i]['@label'] :
                    end_q.append(int(dict_data['annotations']['track'][i]["box"]["@frame"]))
    start_q=sorted(start_q)
    end_q= sorted(end_q)
    print("start_q",start_q)
    print("end_q",end_q)
    shorter_list_count = min(len(start_q), len(end_q))
    for i in range(shorter_list_count):
        start_frame = start_q.pop()
        end_frame = end_q.pop()
        cut_video( j,new_path,data_root_path,start_frame,end_frame)
# Out:
# ------
# 0
# C_2_4_55_BU_SMC_08-20_15-01-34_CA_RGB_DF1_F4_129_533.mp4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1846603/4274243694.py in <module>
#      12     path_parts = j.split('/')
#      13     print(path_parts[-1])
# ---> 14     filtered_items = [item for item in xml_files if path_parts[-1][:-3] in item]
#      15     print(filtered_items[0])
#      16
#
# NameError: name 'xml_files' is not defined

# %%
# Define the file path
file_path = "/home/bigdeal/mnt2/238-1.실내(편의점, 매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CC_RGB_DF1_M4_M4.mp4"
path_parts = file_path.split('/')
print(path_parts[-3])
# Check if "01.원천데이터" is one of the directories in the path
is_source_data_path_parsing = "01.원천데이터" in path_parts

is_source_data_path_parsing

def create_directory_recursively(path):
    try:
        # exist_ok=True 옵션은 해당 경로의 폴더가 이미 존재해도 에러를 발생시키지 않음
        os.makedirs(path, exist_ok=True)
        print(f"'{path}' 디렉토리가 생성되었거나 이미 존재합니다.")
    except PermissionError:
        # 권한 오류 처리
        print(f"권한 오류: '{path}' 디렉토리를 생성할 수 없습니다. 접근 권한을 확인하세요.")
    except Exception as e:
        # 기타 오류 처리
        print(f"오류 발생: {e}")

new_video_dir = os.path.dirname(file_path)
# Create the directory if it doesn't exist
create_directory_recursively(new_video_dir)
# Out:
# 01.원천데이터
# '/home/bigdeal/mnt2/238-1.실내(편의점, 매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.

# %%
with open("/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_14_BU_DYB_10-10_11-39-08_CC_RGB_DF1_F1_F1.xml", 'r', encoding='utf-8') as file:
    xml_string = file.read()
# XML 문자열을 파이썬 딕셔너리로 변환
dict_data = xmltodict.parse(xml_string)
for i in range(len(dict_data['annotations']['track'])):
    if dict_data['annotations']['track'][i]['@label'] in action_list:
        print(dict_data['annotations']['track'][i]['@label'])
        if(isinstance(dict_data['annotations']['track'][i]["box"], list)):
            print(dict_data['annotations']['track'][i]["box"][0]["@frame"])
            if "start" in dict_data['annotations']['track'][i]['@label'] :
                start_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
            if "end" in dict_data['annotations']['track'][i]['@label'] :
                end_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
        else:
            print(dict_data['annotations']['track'][i]["box"]["@frame"])
            if "start" in dict_data['annotations']['track'][i]['@label'] :
                start_q.append(int(dict_data['annotations']['track'][i]["box"]["@frame"]))
            if "end" in dict_data['annotations']['track'][i]['@label'] :
                end_q.append(int(dict_data['annotations']['track'][i]["box"]["@frame"]))
# Out:
# return_start
# {'@frame': '387', '@outside': '1', '@occluded': '0', '@keyframe': '1', '@xtl': '814.54', '@ytl': '493.41', '@xbr': '1023.42', '@ybr': '898.95', '@z_order': '0', 'attribute': [{'@name': 'age group', '#text': 'child'}, {'@name': 'ID', '#text': '2'}, {'@name': 'gender', '#text': 'female'}]}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_545153/2434280105.py in <module>
#       8         print(dict_data['annotations']['track'][i]["box"])
#       9         if "start" in dict_data['annotations']['track'][i]['@label'] :
# ---> 10             start_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
#      11         if "end" in dict_data['annotations']['track'][i]['@label'] :
#      12             end_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
#
# KeyError: 0
