# %%
import cv2

def get_video_fps(video_path):
    # 비디오 파일 열기
    cap = cv2.VideoCapture(video_path)
    
    # 비디오 파일이 열렸는지 확인
    if not cap.isOpened():
        print("비디오 파일을 열 수 없습니다.")
        return None
    
    # FPS 가져오기
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    # 비디오 파일 닫기
    cap.release()
    
    return fps

# 비디오 파일 경로
video_path = 'C_3_12_1_BU_SMC_08-07_13-30-11_CC_RGB_DF2_M1.mp4'

# FPS 가져오기
fps = get_video_fps(video_path)

if fps is not None:
    print("비디오의 FPS는 {}입니다.".format(fps))
# Out:
# 비디오의 FPS는 3.0입니다.

# %%
import cv2

# 비디오 파일 경로
video_path = 'Sample_buying/Sample/01.원천데이터/02.구매행동/02.선택/C_2_2_10_BU_SYA_09-17_16-18-31_CA_RGB_DF1_F1_F1.mp4'

# 비디오 파일 열기
cap = cv2.VideoCapture(video_path)

# 누적 프레임 번호 변수
frame_number = 179
#마지막 1443
#1443-1080= 363
# 프레임 읽기
ret, frame = cap.read()

# 초기화
current_frame_number = cap.get(cv2.CAP_PROP_POS_FRAMES)  # 현재 프레임 번호
frame_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000  # 현재 프레임의 시간(초)

# 반복
while True:

    # 프레임 정보 표시
    cv2.putText(frame, f"Frame: {current_frame_number}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 2)
    cv2.putText(frame, f"Time: {frame_time:.2f} seconds", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 2)

    # 프레임 보여주기
    cv2.imshow('Frame', frame)

    # 키 입력 처리
    key = cv2.waitKey(1) & 0xFF

    # 왼쪽 화살표 키: 이전 프레임으로 이동
    if key == ord('a'):
        frame_number -= 1
        if frame_number < 0:
            frame_number = 0

    # 오른쪽 화살표 키: 다음 프레임으로 이동
    elif key == ord('d'):
        frame_number += 1

    # 'q' 키: 종료
    elif key == ord('q'):
        break

    # 프레임 설정 및 읽기
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
    ret, frame = cap.read()

    # 프레임 정보 업데이트
    current_frame_number = cap.get(cv2.CAP_PROP_POS_FRAMES)  # 현재 프레임 번호
    frame_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000  # 현재 프레임의 시간(초)

# 비디오 해제
cap.release()

# 종료 메시지
print("종료되었습니다.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 48
#      45     break
#      47 # 프레임 설정 및 읽기
# ---> 48 cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
#      49 ret, frame = cap.read()
#      51 # 프레임 정보 업데이트
#
# KeyboardInterrupt:

# %%
import xmltodict
import json

def convert_xml_to_json(xml_file_path, json_file_path):
    # XML 파일을 열고 읽기
    with open(xml_file_path, 'r', encoding='utf-8') as file:
        xml_string = file.read()
    
    # XML 문자열을 파이썬 딕셔너리로 변환
    dict_data = xmltodict.parse(xml_string)
    
    # 딕셔너리를 JSON 파일로 저장
    with open(json_file_path, 'w', encoding='utf-8') as json_file:
        json_file.write(json.dumps(dict_data, indent=4))

# 사용 예제
xml_file_path = 'Sample_buying/Sample/02.라벨링데이터/02.구매행동/02.선택/C_2_2_10_BU_SYA_09-17_16-18-31_CA_RGB_DF1_F1_F1.xml'
# XML 파일을 열고 읽기
with open(xml_file_path, 'r', encoding='utf-8') as file:
    xml_string = file.read()

# XML 문자열을 파이썬 딕셔너리로 변환
dict_data = xmltodict.parse(xml_string)
print(len(dict_data['annotations']['meta']['task']['labels']['label']))

for i in dict_data['annotations']['meta']['task']['labels']['label']:
    print(i["name"])
print(dict_data['annotations']['track'][0].keys())
print(dict_data['annotations']['track'][0]["box"])
print(dict_data['annotations']['track'][0]['@label'])
print(len(dict_data['annotations']['track'][0]['box']))
print(dict_data['annotations']['track'][0]['box'][0].keys())
# Out:
# 33
# Pelvis
# Center head
# return_start
# return_end
# compare_start
# moving
# compare_end
# Left hip
# Left knee
# Left foot
# Right  hip
# Right knee
# Right foot
# Spine naval
# Spine chest
# Neck base
# Right shoulder
# Right elbow
# Right hand
# Left shoulder
# Left elbow
# Left hand
# select_start
# select_end
# test_start
# test_end
# buying_start
# buying_end
# object_snack
# object_drink
# object_groceries
# object_daily necessity
# object_pay
# dict_keys(['@id', '@label', '@source', 'box'])
# [{'@frame': '179', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1430.29', '@ytl': '321.88', '@xbr': '1465.98', '@ybr': '373.00', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '180', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1429.97', '@ytl': '322.20', '@xbr': '1465.65', '@ybr': '373.32', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '181', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1429.65', '@ytl': '322.52', '@xbr': '1465.33', '@ybr': '373.64', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '182', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1429.33', '@ytl': '322.84', '@xbr': '1465.01', '@ybr': '373.96', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '183', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1424.98', '@ytl': '319.95', '@xbr': '1458.26', '@ybr': '368.68', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '184', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1420.64', '@ytl': '317.06', '@xbr': '1451.50', '@ybr': '363.40', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '185', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1410.52', '@ytl': '317.06', '@xbr': '1441.37', '@ybr': '363.40', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '186', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1400.39', '@ytl': '317.06', '@xbr': '1431.25', '@ybr': '363.40', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '187', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1384.96', '@ytl': '322.36', '@xbr': '1415.81', '@ybr': '368.71', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '188', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1369.52', '@ytl': '327.67', '@xbr': '1400.38', '@ybr': '374.01', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '189', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1352.11', '@ytl': '339.39', '@xbr': '1382.99', '@ybr': '388.06', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '190', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1334.70', '@ytl': '351.11', '@xbr': '1365.60', '@ybr': '402.10', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '191', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1319.95', '@ytl': '373.88', '@xbr': '1350.86', '@ybr': '424.20', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '192', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1305.20', '@ytl': '396.65', '@xbr': '1336.13', '@ybr': '446.30', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '193', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1285.80', '@ytl': '423.78', '@xbr': '1319.72', '@ybr': '471.10', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '194', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1266.40', '@ytl': '450.91', '@xbr': '1303.31', '@ybr': '495.90', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '195', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1257.00', '@ytl': '464.30', '@xbr': '1292.59', '@ybr': '508.60', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}]
# object_drink
# 17
# dict_keys(['@frame', '@outside', '@occluded', '@keyframe', '@xtl', '@ytl', '@xbr', '@ybr', '@z_order', 'attribute'])

# %%
import os
def create_directory_recursively(path):
    try:
        # exist_ok=True 옵션은 해당 경로의 폴더가 이미 존재해도 에러를 발생시키지 않음
        os.makedirs(path, exist_ok=True)
        print(f"'{path}' 디렉토리가 생성되었거나 이미 존재합니다.")
    except PermissionError:
        # 권한 오류 처리
        print(f"권한 오류: '{path}' 디렉토리를 생성할 수 없습니다. 접근 권한을 확인하세요.")
    except Exception as e:
        # 기타 오류 처리
        print(f"오류 발생: {e}")
def cut_video(video_path, new_path,data_root_path ,start_frame,end_frame):
    new_video_path=video_path.replace(data_root_path, new_path)
    
    output_path = f'{new_video_path[:-4]}_{start_frame}_{end_frame}.mp4'
    if(os.path.exists(output_path)):
        print("이미 컷편집을 완료했습니다.")
        print("*************")
        return
    # 비디오 캡처 객체 생성
    cap = cv2.VideoCapture(video_path)

    # 총 프레임 수와 FPS 확인
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    # 출력 비디오 설정 (코덱, FPS, 해상도)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    frame_width = int(cap.get(3))
    frame_height = int(cap.get(4))
    new_video_path=video_path.replace(data_root_path, new_path)

    new_video_dir = os.path.dirname(new_video_path)
    # Create the directory if it doesn't exist
    create_directory_recursively(new_video_dir)
    print(output_path)
    
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    current_frame = 0
    while(cap.isOpened()):
        ret, frame = cap.read()
        
        if ret:
            if start_frame <= current_frame <= end_frame:
                out.write(frame)
            
            if current_frame > end_frame:
                break
            
            current_frame += 1
        else:
            break

    # 모든 작업 완료 후 해제
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print("완료")
    print("*************")

# %% [markdown]
# # 컷편집 기능

# %%
import os



def count_mp4_files(path,end):
  """
  주어진 경로와 하위 폴더들을 재귀적으로 탐색하여 mp4 파일 개수를 센다.

  Args:
    path: 탐색을 시작할 경로

  Returns:
    mp4 파일 개수
  """
  mp4_files = []
  mp4_count = 0
  def _count_mp4_files_in_dir(dir_path):
    nonlocal mp4_count
    nonlocal mp4_files
    for file in os.listdir(dir_path):
      full_path = os.path.join(dir_path, file)
      if os.path.isfile(full_path):
        if file.endswith(f".{end}"):
          mp4_count += 1
          mp4_files.append(full_path)
      elif os.path.isdir(full_path):
        _count_mp4_files_in_dir(full_path)

  _count_mp4_files_in_dir(path)

  return mp4_count, mp4_files

# 예시 코드
path = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess"
pathpkl = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcessToPkl"
mp4_count, mp4_files = count_mp4_files(path,"mp4")
pkl_count, pkl_files = count_mp4_files(pathpkl,"pkl")
# xml_count, xml_files = count_mp4_files(path,"xml")

print(f"총 mp4 파일 개수: {mp4_count}")
print(f"총 pkl 파일 개수: {pkl_count}")
# print(f"총 xml 파일 개수: {xml_count}")``
# print(f"mp4 파일 목록: {mp4_files}")
print(f"mp4 파일 목록: {len(mp4_files)}")
print(f"mp4 파일 목록: {mp4_files[0]}")
print(f"mp4 파일 목록: {pkl_files[0]}")
# print(f"mp4 파일 목록: {xml_files[0]}")
# Out:
# 총 mp4 파일 개수: 31064
# 총 pkl 파일 개수: 2763
# mp4 파일 목록: 31064
# mp4 파일 목록: /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMC_08-20_15-01-34_CA_RGB_DF1_F4_129_533.mp4
# mp4 파일 목록: /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcessToPkl/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CC_RGB_DF1_F3_F3_52_180.pkl

# %%
# 영상 파일 경로

for idx, j in enumerate(mp4_files):
    data_root_path= "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터"
    new_path= "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess"
    # XML 파일을 열고 읽기
    print("------")
    print(idx)

    if "매장이동" in j:
        continue
    path_parts = j.split('/')
    print(path_parts[-1])
    filtered_items = [item for item in xml_files if path_parts[-1][:-3] in item]
    print(filtered_items[0])

    action_list= [
"select_start","select_end",
  "test_start", "test_end",
  "buying_start", "buying_end",
  "return_start", "return_end",
  "compare_start", "compare_end"
]
    start_q = []
    end_q = []
    print(j)
    with open(filtered_items[0], 'r', encoding='utf-8') as file:
        xml_string = file.read()
    # XML 문자열을 파이썬 딕셔너리로 변환
    dict_data = xmltodict.parse(xml_string)
    for i in range(len(dict_data['annotations']['track'])):
        if dict_data['annotations']['track'][i]['@label'] in action_list:
            print(dict_data['annotations']['track'][i]['@label'])
            if(isinstance(dict_data['annotations']['track'][i]["box"], list)):
                print(dict_data['annotations']['track'][i]["box"][0]["@frame"])
                if "start" in dict_data['annotations']['track'][i]['@label'] :
                    start_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
                if "end" in dict_data['annotations']['track'][i]['@label'] :
                    end_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
            else:
                print(dict_data['annotations']['track'][i]["box"]["@frame"])
                if "start" in dict_data['annotations']['track'][i]['@label'] :
                    start_q.append(int(dict_data['annotations']['track'][i]["box"]["@frame"]))
                if "end" in dict_data['annotations']['track'][i]['@label'] :
                    end_q.append(int(dict_data['annotations']['track'][i]["box"]["@frame"]))
    start_q=sorted(start_q)
    end_q= sorted(end_q)
    print("start_q",start_q)
    print("end_q",end_q)
    shorter_list_count = min(len(start_q), len(end_q))
    for i in range(shorter_list_count):
        start_frame = start_q.pop()
        end_frame = end_q.pop()
        cut_video( j,new_path,data_root_path,start_frame,end_frame)
# Out:
# ------
# 0
# C_2_4_52_BU_SMB_10-16_18-06-15_CC_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CC_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CC_RGB_DF1_M4_M4.mp4
# buying_start
# 91
# buying_end
# 194
# buying_start
# 406
# buying_end
# 518
# start_q [91, 406]
# end_q [194, 518]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 1
# C_2_4_54_BU_SMB_10-16_18-08-31_CD_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CD_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 105
# buying_end
# 214
# buying_start
# 454
# buying_end
# 553
# start_q [105, 454]
# end_q [214, 553]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 2
# C_2_4_55_BU_SMC_08-20_15-01-34_CA_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SMC_08-20_15-01-34_CA_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMC_08-20_15-01-34_CA_RGB_DF1_F4.mp4
# buying_start
# 129
# buying_end
# 533
# start_q [129]
# end_q [533]
# 이미 컷편집을 완료했습니다.
# ------
# 3
# C_2_4_50_BU_SMC_08-20_14-49-08_CA_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SMC_08-20_14-49-08_CA_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMC_08-20_14-49-08_CA_RGB_DF1_M4.mp4
# buying_start
# 104
# buying_end
# 486
# start_q [104]
# end_q [486]
# 이미 컷편집을 완료했습니다.
# ------
# 4
# C_2_4_51_BU_SMC_08-20_14-51-01_CA_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CA_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CA_RGB_DF1_M4.mp4
# buying_start
# 89
# buying_end
# 490
# start_q [89]
# end_q [490]
# 이미 컷편집을 완료했습니다.
# ------
# 5
# C_2_4_56_BU_SMB_10-16_18-11-42_CB_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CB_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 87
# buying_end
# 179
# buying_start
# 392
# buying_end
# 512
# start_q [87, 392]
# end_q [179, 512]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 6
# C_2_4_52_BU_DYB_10-20_15-41-32_CC_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CC_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 90
# buying_end
# 187
# buying_start
# 378
# buying_end
# 487
# start_q [90, 378]
# end_q [187, 487]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 7
# C_2_4_55_BU_DYA_08-24_17-30-11_CB_RGB_DF1_F2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_DYA_08-24_17-30-11_CB_RGB_DF1_F2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_DYA_08-24_17-30-11_CB_RGB_DF1_F2_M2.mp4
# buying_start
# 99
# buying_end
# 242
# buying_start
# 420
# buying_end
# 547
# start_q [99, 420]
# end_q [242, 547]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 8
# C_2_4_55_BU_SMB_10-16_18-10-10_CC_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CC_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 98
# buying_end
# 202
# buying_start
# 394
# buying_end
# 486
# start_q [98, 394]
# end_q [202, 486]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 9
# C_2_4_52_BU_SYB_10-16_18-17-48_CA_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CA_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CA_RGB_DF1_M4_M4.mp4
# buying_start
# 72
# buying_end
# 234
# buying_start
# 417
# buying_end
# 561
# start_q [72, 417]
# end_q [234, 561]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 10
# C_2_4_51_BU_SMC_08-20_14-51-01_CB_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CB_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CB_RGB_DF1_M4.mp4
# buying_start
# 112
# buying_end
# 488
# start_q [112]
# end_q [488]
# 이미 컷편집을 완료했습니다.
# ------
# 11
# C_2_4_54_BU_SYB_10-16_18-19-27_CB_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CB_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 57
# buying_end
# 184
# buying_start
# 356
# buying_end
# 515
# start_q [57, 356]
# end_q [184, 515]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 12
# C_2_4_50_BU_SMC_08-20_14-49-09_CC_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SMC_08-20_14-49-09_CC_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMC_08-20_14-49-09_CC_RGB_DF1_M4.mp4
# buying_start
# 102
# buying_end
# 484
# start_q [102]
# end_q [484]
# 이미 컷편집을 완료했습니다.
# ------
# 13
# C_2_4_52_BU_DYB_10-20_15-41-32_CD_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CD_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 90
# buying_end
# 188
# buying_start
# 377
# buying_end
# 487
# start_q [90, 377]
# end_q [188, 487]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 14
# C_2_4_51_BU_SYB_10-16_18-16-32_CD_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CD_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CD_RGB_DF1_M4_M4.mp4
# buying_start
# 71
# buying_end
# 213
# buying_start
# 392
# buying_end
# 565
# start_q [71, 392]
# end_q [213, 565]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 15
# C_2_4_54_BU_SMC_08-20_14-59-10_CC_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-10_CC_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-10_CC_RGB_DF1_F4.mp4
# buying_start
# 128
# buying_end
# 500
# start_q [128]
# end_q [500]
# 이미 컷편집을 완료했습니다.
# ------
# 16
# C_2_4_55_BU_SYB_10-16_18-20-51_CD_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CD_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 78
# buying_end
# 230
# buying_start
# 399
# buying_end
# 544
# start_q [78, 399]
# end_q [230, 544]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 17
# C_2_4_55_BU_SMB_10-16_18-10-10_CB_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CB_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 100
# buying_end
# 202
# buying_start
# 396
# buying_end
# 487
# start_q [100, 396]
# end_q [202, 487]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 18
# C_2_4_56_BU_DYB_10-20_09-22-28_CD_RGB_DF1_M2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CD_RGB_DF1_M2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CD_RGB_DF1_M2_M2.mp4
# buying_start
# 71
# buying_end
# 197
# start_q [71]
# end_q [197]
# 이미 컷편집을 완료했습니다.
# ------
# 19
# C_2_4_53_BU_DYB_10-20_15-42-46_CD_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CD_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 90
# buying_end
# 196
# buying_start
# 360
# buying_end
# 446
# start_q [90, 360]
# end_q [196, 446]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 20
# C_2_4_54_BU_SMB_10-16_18-08-31_CA_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CA_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 88
# buying_end
# 217
# buying_start
# 443
# buying_end
# 553
# start_q [88, 443]
# end_q [217, 553]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 21
# C_2_4_54_BU_SMB_10-16_18-08-31_CB_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CB_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 91
# buying_end
# 217
# buying_start
# 443
# buying_end
# 553
# start_q [91, 443]
# end_q [217, 553]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 22
# C_2_4_54_BU_SYB_10-16_18-19-27_CC_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CC_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 54
# buying_end
# 180
# buying_start
# 352
# buying_end
# 512
# start_q [54, 352]
# end_q [180, 512]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 23
# C_2_4_49_BU_SMC_08-20_14-46-36_CA_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_49_BU_SMC_08-20_14-46-36_CA_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SMC_08-20_14-46-36_CA_RGB_DF1_M4.mp4
# buying_start
# 68
# buying_end
# 449
# start_q [68]
# end_q [449]
# 이미 컷편집을 완료했습니다.
# ------
# 24
# C_2_4_53_BU_SMC_08-20_14-56-32_CC_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_53_BU_SMC_08-20_14-56-32_CC_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_SMC_08-20_14-56-32_CC_RGB_DF1_F4.mp4
# buying_start
# 98
# buying_end
# 466
# start_q [98]
# end_q [466]
# 이미 컷편집을 완료했습니다.
# ------
# 25
# C_2_4_50_BU_SMB_10-16_18-03-05_CD_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CD_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CD_RGB_DF1_M4_M4.mp4
# buying_start
# 131
# buying_end
# 285
# buying_start
# 465
# buying_end
# 580
# start_q [131, 465]
# end_q [285, 580]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 26
# C_2_4_49_BU_SMC_08-20_14-46-36_CB_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_49_BU_SMC_08-20_14-46-36_CB_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SMC_08-20_14-46-36_CB_RGB_DF1_M4.mp4
# buying_start
# 65
# buying_end
# 447
# start_q [65]
# end_q [447]
# 이미 컷편집을 완료했습니다.
# ------
# 27
# C_2_4_50_BU_SYB_10-16_18-15-05_CB_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CB_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 65
# buying_end
# 216
# buying_start
# 394
# buying_end
# 563
# start_q [65, 394]
# end_q [216, 563]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 28
# C_2_4_50_BU_DYB_10-20_15-38-31_CA_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CA_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 80
# buying_end
# 184
# buying_start
# 368
# buying_end
# 459
# start_q [80, 368]
# end_q [184, 459]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 29
# C_2_4_56_BU_SMB_10-16_18-11-42_CD_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CD_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 85
# buying_end
# 181
# buying_start
# 380
# buying_end
# 512
# start_q [85, 380]
# end_q [181, 512]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 30
# C_2_4_55_BU_SMB_10-16_18-10-10_CD_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CD_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 97
# buying_end
# 199
# buying_start
# 388
# buying_end
# 487
# start_q [97, 388]
# end_q [199, 487]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 31
# C_2_4_49_BU_SYB_10-16_14-06-43_CD_RGB_DF1_F3_F3.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CD_RGB_DF1_F3_F3.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CD_RGB_DF1_F3_F3.mp4
# buying_start
# 52
# buying_end
# 180
# buying_start
# 320
# buying_end
# 433
# start_q [52, 320]
# end_q [180, 433]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 32
# C_2_4_51_BU_SMB_10-16_18-04-45_CB_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CB_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 108
# buying_end
# 245
# buying_start
# 429
# buying_end
# 561
# start_q [108, 429]
# end_q [245, 561]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 33
# C_2_4_52_BU_SMC_08-20_14-53-08_CA_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SMC_08-20_14-53-08_CA_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMC_08-20_14-53-08_CA_RGB_DF1_M4.mp4
# buying_start
# 110
# buying_end
# 485
# start_q [110]
# end_q [485]
# 이미 컷편집을 완료했습니다.
# ------
# 34
# C_2_4_55_BU_SYB_10-16_18-20-51_CC_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CC_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 78
# buying_end
# 229
# buying_start
# 399
# buying_end
# 544
# start_q [78, 399]
# end_q [229, 544]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 35
# C_2_4_53_BU_DYB_10-20_15-42-46_CC_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CC_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 90
# buying_end
# 196
# buying_start
# 360
# buying_end
# 446
# start_q [90, 360]
# end_q [196, 446]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 36
# C_2_4_52_BU_SMC_08-20_14-53-09_CC_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SMC_08-20_14-53-09_CC_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMC_08-20_14-53-09_CC_RGB_DF1_M4.mp4
# buying_start
# 80
# buying_end
# 479
# start_q [80]
# end_q [479]
# 이미 컷편집을 완료했습니다.
# ------
# 37
# C_2_4_51_BU_SMB_10-16_18-04-45_CD_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CD_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CD_RGB_DF1_M4_M4.mp4
# buying_start
# 112
# buying_end
# 249
# buying_start
# 442
# buying_end
# 564
# start_q [112, 442]
# end_q [249, 564]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 38
# C_2_4_50_BU_SMB_10-16_18-03-05_CA_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CA_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CA_RGB_DF1_M4_M4.mp4
# buying_start
# 130
# buying_end
# 285
# buying_start
# 466
# buying_end
# 580
# start_q [130, 466]
# end_q [285, 580]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 39
# C_2_4_50_BU_SMB_10-16_18-03-05_CB_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CB_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 130
# buying_end
# 287
# buying_start
# 470
# buying_end
# 581
# start_q [130, 470]
# end_q [287, 581]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 40
# C_2_4_54_BU_SMC_08-20_14-59-09_CA_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-09_CA_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-09_CA_RGB_DF1_F4.mp4
# buying_start
# 136
# buying_end
# 503
# start_q [136]
# end_q [503]
# 이미 컷편집을 완료했습니다.
# ------
# 41
# C_2_4_56_BU_DYA_08-24_17-32-40_CB_RGB_DF1_F2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-40_CB_RGB_DF1_F2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-40_CB_RGB_DF1_F2_M2.mp4
# buying_start
# 107
# buying_end
# 242
# buying_start
# 370
# buying_end
# 512
# start_q [107, 370]
# end_q [242, 512]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 42
# C_2_4_54_BU_SMB_10-16_18-08-31_CC_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CC_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 103
# buying_end
# 215
# buying_start
# 453
# buying_end
# 552
# start_q [103, 453]
# end_q [215, 552]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 43
# C_2_4_54_BU_DYA_08-24_17-26-08_CB_RGB_DF1_F2_F2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CB_RGB_DF1_F2_F2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CB_RGB_DF1_F2_F2.mp4
# buying_start
# 98
# buying_end
# 226
# buying_start
# 328
# buying_end
# 478
# start_q [98, 328]
# end_q [226, 478]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 44
# C_2_4_51_BU_SMC_08-20_14-51-01_CC_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CC_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CC_RGB_DF1_M4.mp4
# buying_start
# 112
# buying_end
# 489
# start_q [112]
# end_q [489]
# 이미 컷편집을 완료했습니다.
# ------
# 45
# C_2_4_51_BU_SYB_10-16_18-16-32_CB_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CB_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 72
# buying_end
# 213
# buying_start
# 392
# buying_end
# 567
# start_q [72, 392]
# end_q [213, 567]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 46
# C_2_4_55_BU_SYB_10-16_18-20-51_CA_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CA_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 83
# buying_end
# 232
# buying_start
# 402
# buying_end
# 544
# start_q [83, 402]
# end_q [232, 544]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 47
# C_2_4_54_BU_DYA_08-24_17-26-08_CA_RGB_DF1_F2_F2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CA_RGB_DF1_F2_F2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CA_RGB_DF1_F2_F2.mp4
# buying_start
# 102
# buying_end
# 230
# buying_start
# 333
# buying_end
# 482
# start_q [102, 333]
# end_q [230, 482]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 48
# C_2_4_56_BU_DYA_08-24_17-32-41_CC_RGB_DF1_F2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-41_CC_RGB_DF1_F2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-41_CC_RGB_DF1_F2_M2.mp4
# buying_start
# 107
# buying_end
# 242
# buying_start
# 370
# buying_end
# 511
# start_q [107, 370]
# end_q [242, 511]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 49
# C_2_4_56_BU_SMC_08-20_15-03-31_CA_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_SMC_08-20_15-03-31_CA_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMC_08-20_15-03-31_CA_RGB_DF1_F4.mp4
# buying_start
# 114
# buying_end
# 509
# start_q [114]
# end_q [509]
# 이미 컷편집을 완료했습니다.
# ------
# 50
# C_2_4_56_BU_DYB_10-20_09-22-28_CC_RGB_DF1_M2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CC_RGB_DF1_M2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CC_RGB_DF1_M2_M2.mp4
# buying_start
# 72
# buying_end
# 197
# buying_start
# 392
# buying_end
# 499
# start_q [72, 392]
# end_q [197, 499]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 51
# C_2_4_54_BU_SMC_08-20_14-59-10_CB_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-10_CB_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-10_CB_RGB_DF1_F4.mp4
# buying_start
# 131
# buying_end
# 500
# start_q [131]
# end_q [500]
# 이미 컷편집을 완료했습니다.
# ------
# 52
# C_2_4_50_BU_DYB_10-20_15-38-31_CD_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CD_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 86
# buying_end
# 190
# buying_start
# 375
# buying_end
# 467
# start_q [86, 375]
# end_q [190, 467]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 53
# C_2_4_51_BU_SYB_10-16_18-16-32_CC_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CC_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CC_RGB_DF1_M4_M4.mp4
# buying_start
# 69
# buying_end
# 211
# buying_start
# 395
# buying_end
# 567
# start_q [69, 395]
# end_q [211, 567]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 54
# C_2_4_52_BU_DYB_10-20_15-41-32_CB_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CB_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 81
# buying_end
# 178
# buying_start
# 367
# buying_end
# 477
# start_q [81, 367]
# end_q [178, 477]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 55
# C_2_4_49_BU_SYB_10-16_14-06-43_CC_RGB_DF1_F3_F3.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CC_RGB_DF1_F3_F3.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CC_RGB_DF1_F3_F3.mp4
# buying_start
# 52
# buying_end
# 180
# buying_start
# 320
# buying_end
# 433
# start_q [52, 320]
# end_q [180, 433]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 56
# C_2_4_56_BU_SMC_08-20_15-03-31_CB_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_SMC_08-20_15-03-31_CB_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMC_08-20_15-03-31_CB_RGB_DF1_F4.mp4
# buying_start
# 110
# buying_end
# 506
# start_q [110]
# end_q [506]
# 이미 컷편집을 완료했습니다.
# ------
# 57
# C_2_4_51_BU_SYB_10-16_18-16-32_CA_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CA_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CA_RGB_DF1_M4_M4.mp4
# buying_start
# 72
# buying_end
# 213
# buying_start
# 392
# buying_end
# 567
# start_q [72, 392]
# end_q [213, 567]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 58
# C_2_4_54_BU_DYB_10-20_15-44-16_CB_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CB_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 72
# buying_end
# 172
# buying_start
# 415
# buying_end
# 511
# start_q [72, 415]
# end_q [172, 511]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 59
# C_2_4_53_BU_DYB_10-20_15-42-46_CA_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CA_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 84
# buying_end
# 197
# buying_start
# 369
# buying_end
# 463
# start_q [84, 369]
# end_q [197, 463]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 60
# C_2_4_50_BU_SYB_10-16_18-15-05_CA_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CA_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CA_RGB_DF1_M4_M4.mp4
# buying_start
# 60
# buying_end
# 215
# buying_start
# 394
# buying_end
# 563
# start_q [60, 394]
# end_q [215, 563]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 61
# C_2_4_54_BU_DYB_10-20_15-44-16_CA_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CA_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 73
# buying_end
# 172
# buying_start
# 417
# buying_end
# 510
# start_q [73, 417]
# end_q [172, 510]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 62
# C_2_4_50_BU_DYB_10-20_15-38-31_CC_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CC_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 86
# buying_end
# 190
# buying_start
# 375
# buying_end
# 466
# start_q [86, 375]
# end_q [190, 466]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 63
# C_2_4_56_BU_SMB_10-16_18-11-42_CC_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CC_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 85
# buying_end
# 181
# buying_start
# 380
# buying_end
# 512
# start_q [85, 380]
# end_q [181, 512]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 64
# C_2_4_52_BU_SYB_10-16_18-17-48_CD_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CD_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CD_RGB_DF1_M4_M4.mp4
# buying_start
# 70
# buying_end
# 235
# buying_start
# 416
# buying_end
# 559
# start_q [70, 416]
# end_q [235, 559]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 65
# C_2_4_52_BU_SMB_10-16_18-06-15_CB_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CB_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 93
# buying_end
# 202
# buying_start
# 408
# buying_end
# 521
# start_q [93, 408]
# end_q [202, 521]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 66
# C_2_4_54_BU_SYB_10-16_18-19-27_CD_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CD_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 55
# buying_end
# 180
# buying_start
# 353
# buying_end
# 511
# start_q [55, 353]
# end_q [180, 511]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 67
# C_2_4_52_BU_SYB_10-16_18-17-48_CC_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CC_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CC_RGB_DF1_M4_M4.mp4
# buying_start
# 65
# buying_end
# 235
# buying_start
# 415
# buying_end
# 559
# start_q [65, 415]
# end_q [235, 559]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 68
# C_2_4_49_BU_SMC_08-20_14-46-36_CC_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_49_BU_SMC_08-20_14-46-36_CC_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SMC_08-20_14-46-36_CC_RGB_DF1_M4.mp4
# buying_start
# 66
# buying_end
# 448
# start_q [66]
# end_q [448]
# 이미 컷편집을 완료했습니다.
# ------
# 69
# C_2_4_52_BU_DYB_10-20_15-41-32_CA_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CA_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 81
# buying_end
# 177
# buying_start
# 367
# buying_end
# 477
# start_q [81, 367]
# end_q [177, 477]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 70
# C_2_4_50_BU_SMB_10-16_18-03-05_CC_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CC_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CC_RGB_DF1_M4_M4.mp4
# buying_start
# 130
# buying_end
# 285
# buying_start
# 465
# buying_end
# 580
# start_q [130, 465]
# end_q [285, 580]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 71
# C_2_4_55_BU_SYB_10-16_18-20-51_CB_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CB_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 82
# buying_end
# 232
# buying_start
# 402
# buying_end
# 545
# start_q [82, 402]
# end_q [232, 545]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 72
# C_2_4_55_BU_SMC_08-20_15-01-34_CB_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SMC_08-20_15-01-34_CB_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMC_08-20_15-01-34_CB_RGB_DF1_F4.mp4
# buying_start
# 129
# buying_end
# 531
# start_q [129]
# end_q [531]
# 이미 컷편집을 완료했습니다.
# ------
# 73
# C_2_4_49_BU_SYB_10-16_14-06-43_CB_RGB_DF1_F3_F3.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CB_RGB_DF1_F3_F3.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CB_RGB_DF1_F3_F3.mp4
# buying_start
# 61
# buying_end
# 188
# buying_start
# 326
# buying_end
# 441
# start_q [61, 326]
# end_q [188, 441]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 74
# C_2_4_51_BU_SMB_10-16_18-04-45_CA_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CA_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CA_RGB_DF1_M4_M4.mp4
# buying_start
# 108
# buying_end
# 246
# buying_start
# 432
# buying_end
# 561
# start_q [108, 432]
# end_q [246, 561]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 75
# C_2_4_54_BU_DYB_10-20_15-44-16_CD_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CD_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 78
# buying_end
# 172
# buying_start
# 403
# buying_end
# 497
# start_q [78, 403]
# end_q [172, 497]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 76
# C_2_4_55_BU_DYA_08-24_17-30-11_CA_RGB_DF1_F2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_DYA_08-24_17-30-11_CA_RGB_DF1_F2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_DYA_08-24_17-30-11_CA_RGB_DF1_F2_M2.mp4
# buying_start
# 102
# buying_end
# 246
# buying_start
# 423
# buying_end
# 550
# start_q [102, 423]
# end_q [246, 550]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 77
# C_2_4_55_BU_DYA_08-24_17-30-11_CC_RGB_DF1_F2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_DYA_08-24_17-30-11_CC_RGB_DF1_F2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_DYA_08-24_17-30-11_CC_RGB_DF1_F2_M2.mp4
# buying_start
# 101
# buying_end
# 242
# buying_start
# 420
# buying_end
# 548
# start_q [101, 420]
# end_q [242, 548]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 78
# C_2_4_56_BU_SMB_10-16_18-11-42_CA_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CA_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 87
# buying_end
# 179
# buying_start
# 392
# buying_end
# 512
# start_q [87, 392]
# end_q [179, 512]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 79
# C_2_4_50_BU_SMC_08-20_14-49-09_CB_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SMC_08-20_14-49-09_CB_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMC_08-20_14-49-09_CB_RGB_DF1_M4.mp4
# buying_start
# 100
# buying_end
# 483
# start_q [100]
# end_q [483]
# 이미 컷편집을 완료했습니다.
# ------
# 80
# C_2_4_52_BU_SYB_10-16_18-17-48_CB_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CB_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 71
# buying_end
# 235
# buying_start
# 417
# buying_end
# 561
# start_q [71, 417]
# end_q [235, 561]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 81
# C_2_4_53_BU_SMC_08-20_14-56-31_CA_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_53_BU_SMC_08-20_14-56-31_CA_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_SMC_08-20_14-56-31_CA_RGB_DF1_F4.mp4
# buying_start
# 99
# buying_end
# 466
# start_q [99]
# end_q [466]
# 이미 컷편집을 완료했습니다.
# ------
# 82
# C_2_4_54_BU_SYB_10-16_18-19-27_CA_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CA_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 57
# buying_end
# 184
# buying_start
# 353
# buying_end
# 514
# start_q [57, 353]
# end_q [184, 514]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 83
# C_2_4_50_BU_DYB_10-20_15-38-31_CB_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CB_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 80
# buying_end
# 184
# buying_start
# 368
# buying_end
# 459
# start_q [80, 368]
# end_q [184, 459]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 84
# C_2_4_54_BU_DYB_10-20_15-44-16_CC_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CC_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 80
# buying_end
# 170
# buying_start
# 406
# buying_end
# 495
# start_q [80, 406]
# end_q [170, 495]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 85
# C_2_4_50_BU_SYB_10-16_18-15-05_CC_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CC_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CC_RGB_DF1_M4_M4.mp4
# buying_start
# 65
# buying_end
# 215
# buying_start
# 394
# buying_end
# 563
# start_q [65, 394]
# end_q [215, 563]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 86
# C_2_4_51_BU_SMB_10-16_18-04-45_CC_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CC_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CC_RGB_DF1_M4_M4.mp4
# buying_start
# 112
# buying_end
# 250
# buying_start
# 436
# buying_end
# 564
# start_q [112, 436]
# end_q [250, 564]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 87
# C_2_4_52_BU_SMC_08-20_14-53-09_CB_RGB_DF1_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SMC_08-20_14-53-09_CB_RGB_DF1_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMC_08-20_14-53-09_CB_RGB_DF1_M4.mp4
# buying_start
# 106
# buying_end
# 480
# start_q [106]
# end_q [480]
# 이미 컷편집을 완료했습니다.
# ------
# 88
# C_2_4_52_BU_SMB_10-16_18-06-15_CD_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CD_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CD_RGB_DF1_M4_M4.mp4
# buying_start
# 79
# buying_end
# 195
# buying_start
# 406
# buying_end
# 506
# start_q [79, 406]
# end_q [195, 506]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 89
# C_2_4_49_BU_SYB_10-16_14-06-43_CA_RGB_DF1_F3_F3.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CA_RGB_DF1_F3_F3.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CA_RGB_DF1_F3_F3.mp4
# buying_start
# 62
# buying_end
# 189
# buying_start
# 328
# buying_end
# 442
# start_q [62, 328]
# end_q [189, 442]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 90
# C_2_4_53_BU_DYB_10-20_15-42-46_CB_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CB_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 83
# buying_end
# 197
# buying_start
# 372
# buying_end
# 463
# start_q [83, 372]
# end_q [197, 463]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 91
# C_2_4_52_BU_SMB_10-16_18-06-15_CA_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CA_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CA_RGB_DF1_M4_M4.mp4
# buying_start
# 93
# buying_end
# 195
# buying_start
# 408
# buying_end
# 521
# start_q [93, 408]
# end_q [195, 521]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 92
# C_2_4_50_BU_SYB_10-16_18-15-05_CD_RGB_DF1_M4_M4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CD_RGB_DF1_M4_M4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CD_RGB_DF1_M4_M4.mp4
# buying_start
# 65
# buying_end
# 215
# buying_start
# 394
# buying_end
# 563
# start_q [65, 394]
# end_q [215, 563]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 93
# C_2_4_56_BU_DYB_10-20_09-22-28_CB_RGB_DF1_M2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CB_RGB_DF1_M2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CB_RGB_DF1_M2_M2.mp4
# buying_start
# 64
# buying_end
# 189
# buying_start
# 383
# buying_end
# 491
# start_q [64, 383]
# end_q [189, 491]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 94
# C_2_4_55_BU_SMC_08-20_15-01-35_CC_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SMC_08-20_15-01-35_CC_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMC_08-20_15-01-35_CC_RGB_DF1_F4.mp4
# buying_start
# 129
# buying_end
# 531
# start_q [129]
# end_q [531]
# 이미 컷편집을 완료했습니다.
# ------
# 95
# C_2_4_53_BU_SMC_08-20_14-56-31_CB_RGB_DF1_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_53_BU_SMC_08-20_14-56-31_CB_RGB_DF1_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_SMC_08-20_14-56-31_CB_RGB_DF1_F4.mp4
# buying_start
# 81
# buying_end
# 465
# start_q [81]
# end_q [465]
# 이미 컷편집을 완료했습니다.
# ------
# 96
# C_2_4_56_BU_DYB_10-20_09-22-28_CA_RGB_DF1_M2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CA_RGB_DF1_M2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CA_RGB_DF1_M2_M2.mp4
# buying_start
# 64
# buying_end
# 189
# buying_start
# 383
# buying_end
# 491
# start_q [64, 383]
# end_q [189, 491]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 97
# C_2_4_56_BU_DYA_08-24_17-32-40_CA_RGB_DF1_F2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-40_CA_RGB_DF1_F2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-40_CA_RGB_DF1_F2_M2.mp4
# buying_start
# 113
# buying_end
# 246
# buying_start
# 374
# buying_end
# 517
# start_q [113, 374]
# end_q [246, 517]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 98
# C_2_4_55_BU_SMB_10-16_18-10-10_CA_RGB_DF1_F4_F4.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CA_RGB_DF1_F4_F4.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 98
# buying_end
# 201
# buying_start
# 396
# buying_end
# 487
# start_q [98, 396]
# end_q [201, 487]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 99
# C_2_4_54_BU_DYA_08-24_17-26-08_CC_RGB_DF1_F2_F2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CC_RGB_DF1_F2_F2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CC_RGB_DF1_F2_F2.mp4
# buying_start
# 98
# buying_end
# 225
# buying_start
# 328
# buying_end
# 478
# start_q [98, 328]
# end_q [225, 478]
# 이미 컷편집을 완료했습니다.
# 이미 컷편집을 완료했습니다.
# ------
# 100
# ...
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_5_BU_DYB_10-10_14-38-46_CD_RGB_DF1_M1_M1.mp4
# return_start
# 76
# return_end
# 228
# return_start
# 389
# return_end
# 541
# start_q [76, 389]
# end_q [228, 541]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_5_BU_DYB_10-10_14-38-46_CD_RGB_DF1_M1_M1_389_541.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_5_BU_DYB_10-10_14-38-46_CD_RGB_DF1_M1_M1_76_228.mp4
# 완료
# ------
# 873
# C_2_5_11_BU_DYB_10-10_11-35-42_CD_RGB_DF1_F1_F1.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_11_BU_DYB_10-10_11-35-42_CD_RGB_DF1_F1_F1.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_11_BU_DYB_10-10_11-35-42_CD_RGB_DF1_F1_F1.mp4
# return_start
# 65
# return_end
# 216
# return_start
# 370
# return_end
# 518
# start_q [65, 370]
# end_q [216, 518]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_11_BU_DYB_10-10_11-35-42_CD_RGB_DF1_F1_F1_370_518.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_11_BU_DYB_10-10_11-35-42_CD_RGB_DF1_F1_F1_65_216.mp4
# 완료
# ------
# 874
# C_2_5_36_BU_SYA_09-15_15-30-42_CC_RGB_DF1_M3_M3.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_36_BU_SYA_09-15_15-30-42_CC_RGB_DF1_M3_M3.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_36_BU_SYA_09-15_15-30-42_CC_RGB_DF1_M3_M3.mp4
# return_start
# 69
# return_end
# 213
# return_start
# 351
# return_end
# 520
# start_q [69, 351]
# end_q [213, 520]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_36_BU_SYA_09-15_15-30-42_CC_RGB_DF1_M3_M3_351_520.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_36_BU_SYA_09-15_15-30-42_CC_RGB_DF1_M3_M3_69_213.mp4
# 완료
# ------
# 875
# C_2_5_80_BU_SYB_10-16_19-32-44_CA_RGB_DF1_M2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_80_BU_SYB_10-16_19-32-44_CA_RGB_DF1_M2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_80_BU_SYB_10-16_19-32-44_CA_RGB_DF1_M2_M2.mp4
# return_start
# 86
# return_end
# 237
# return_start
# 392
# return_end
# 549
# start_q [86, 392]
# end_q [237, 549]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_80_BU_SYB_10-16_19-32-44_CA_RGB_DF1_M2_M2_392_549.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_80_BU_SYB_10-16_19-32-44_CA_RGB_DF1_M2_M2_86_237.mp4
# 완료
# ------
# 876
# C_2_5_74_BU_SYB_10-16_15-49-29_CB_RGB_DF1_F1_F1.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_74_BU_SYB_10-16_15-49-29_CB_RGB_DF1_F1_F1.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_74_BU_SYB_10-16_15-49-29_CB_RGB_DF1_F1_F1.mp4
# return_start
# 43
# return_end
# 177
# return_start
# 308
# return_end
# 444
# start_q [43, 308]
# end_q [177, 444]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_74_BU_SYB_10-16_15-49-29_CB_RGB_DF1_F1_F1_308_444.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_74_BU_SYB_10-16_15-49-29_CB_RGB_DF1_F1_F1_43_177.mp4
# 완료
# ------
# 877
# C_2_5_15_BU_SYB_10-16_12-07-05_CC_RGB_DF1_M2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_15_BU_SYB_10-16_12-07-05_CC_RGB_DF1_M2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_15_BU_SYB_10-16_12-07-05_CC_RGB_DF1_M2_M2.mp4
# return_start
# 83
# return_end
# 227
# return_start
# 357
# return_end
# 492
# start_q [83, 357]
# end_q [227, 492]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_15_BU_SYB_10-16_12-07-05_CC_RGB_DF1_M2_M2_357_492.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_15_BU_SYB_10-16_12-07-05_CC_RGB_DF1_M2_M2_83_227.mp4
# 완료
# ------
# 878
# C_2_5_45_BU_SYB_10-16_17-33-10_CB_RGB_DF1_M3_M3.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_45_BU_SYB_10-16_17-33-10_CB_RGB_DF1_M3_M3.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_45_BU_SYB_10-16_17-33-10_CB_RGB_DF1_M3_M3.mp4
# return_start
# 67
# return_end
# 173
# return_start
# 361
# return_end
# 470
# start_q [67, 361]
# end_q [173, 470]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_45_BU_SYB_10-16_17-33-10_CB_RGB_DF1_M3_M3_361_470.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_45_BU_SYB_10-16_17-33-10_CB_RGB_DF1_M3_M3_67_173.mp4
# 완료
# ------
# 879
# C_2_5_14_BU_DYA_07-26_18-25-08_CC_RGB_DF1_F2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_14_BU_DYA_07-26_18-25-08_CC_RGB_DF1_F2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_14_BU_DYA_07-26_18-25-08_CC_RGB_DF1_F2_M2.mp4
# return_start
# 102
# return_end
# 224
# return_start
# 405
# return_end
# 541
# start_q [102, 405]
# end_q [224, 541]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_14_BU_DYA_07-26_18-25-08_CC_RGB_DF1_F2_M2_405_541.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_14_BU_DYA_07-26_18-25-08_CC_RGB_DF1_F2_M2_102_224.mp4
# 완료
# ------
# 880
# C_2_5_21_BU_DYA_08-05_13-49-16_CC_RGB_DF1_F3_M3.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_21_BU_DYA_08-05_13-49-16_CC_RGB_DF1_F3_M3.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_21_BU_DYA_08-05_13-49-16_CC_RGB_DF1_F3_M3.mp4
# return_start
# 82
# return_end
# 231
# return_start
# 388
# return_end
# 542
# start_q [82, 388]
# end_q [231, 542]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_21_BU_DYA_08-05_13-49-16_CC_RGB_DF1_F3_M3_388_542.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_21_BU_DYA_08-05_13-49-16_CC_RGB_DF1_F3_M3_82_231.mp4
# 완료
# ------
# 881
# C_2_5_50_BU_DYB_10-10_13-54-52_CC_RGB_DF1_F2_F2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_50_BU_DYB_10-10_13-54-52_CC_RGB_DF1_F2_F2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_50_BU_DYB_10-10_13-54-52_CC_RGB_DF1_F2_F2.mp4
# return_start
# 72
# return_end
# 204
# return_start
# 378
# return_end
# 528
# start_q [72, 378]
# end_q [204, 528]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_50_BU_DYB_10-10_13-54-52_CC_RGB_DF1_F2_F2_378_528.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_50_BU_DYB_10-10_13-54-52_CC_RGB_DF1_F2_F2_72_204.mp4
# 완료
# ------
# 882
# C_2_5_42_BU_SYA_09-15_15-39-44_CB_RGB_DF1_M3_M3.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_42_BU_SYA_09-15_15-39-44_CB_RGB_DF1_M3_M3.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_42_BU_SYA_09-15_15-39-44_CB_RGB_DF1_M3_M3.mp4
# return_start
# 62
# return_end
# 222
# return_start
# 369
# return_end
# 493
# start_q [62, 369]
# end_q [222, 493]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_42_BU_SYA_09-15_15-39-44_CB_RGB_DF1_M3_M3_369_493.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_42_BU_SYA_09-15_15-39-44_CB_RGB_DF1_M3_M3_62_222.mp4
# 완료
# ------
# 883
# C_2_5_55_BU_DYB_10-10_14-06-30_CD_RGB_DF1_F2_F2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_55_BU_DYB_10-10_14-06-30_CD_RGB_DF1_F2_F2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_55_BU_DYB_10-10_14-06-30_CD_RGB_DF1_F2_F2.mp4
# return_start
# 78
# return_end
# 213
# return_start
# 404
# return_end
# 533
# start_q [78, 404]
# end_q [213, 533]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_55_BU_DYB_10-10_14-06-30_CD_RGB_DF1_F2_F2_404_533.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_55_BU_DYB_10-10_14-06-30_CD_RGB_DF1_F2_F2_78_213.mp4
# 완료
# ------
# 884
# C_2_5_05_BU_DYA_07-26_18-01-14_CA_RGB_DF1_M2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_05_BU_DYA_07-26_18-01-14_CA_RGB_DF1_M2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_05_BU_DYA_07-26_18-01-14_CA_RGB_DF1_M2_M2.mp4
# return_start
# 82
# return_end
# 181
# return_start
# 344
# return_end
# 461
# start_q [82, 344]
# end_q [181, 461]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_05_BU_DYA_07-26_18-01-14_CA_RGB_DF1_M2_M2_344_461.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_05_BU_DYA_07-26_18-01-14_CA_RGB_DF1_M2_M2_82_181.mp4
# 완료
# ------
# 885
# C_2_5_10_BU_DYA_07-26_18-16-22_CB_RGB_DF1_F2_F2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_10_BU_DYA_07-26_18-16-22_CB_RGB_DF1_F2_F2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_10_BU_DYA_07-26_18-16-22_CB_RGB_DF1_F2_F2.mp4
# return_start
# 112
# return_end
# 236
# return_start
# 372
# return_end
# 515
# start_q [112, 372]
# end_q [236, 515]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_10_BU_DYA_07-26_18-16-22_CB_RGB_DF1_F2_F2_372_515.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_10_BU_DYA_07-26_18-16-22_CB_RGB_DF1_F2_F2_112_236.mp4
# 완료
# ------
# 886
# C_2_5_44_BU_DYA_08-05_14-18-26_CC_RGB_DF1_M3_F3.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_44_BU_DYA_08-05_14-18-26_CC_RGB_DF1_M3_F3.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_44_BU_DYA_08-05_14-18-26_CC_RGB_DF1_M3_F3.mp4
# return_start
# 101
# return_end
# 272
# return_start
# 403
# return_end
# 554
# start_q [101, 403]
# end_q [272, 554]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_44_BU_DYA_08-05_14-18-26_CC_RGB_DF1_M3_F3_403_554.mp4
# 완료
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_44_BU_DYA_08-05_14-18-26_CC_RGB_DF1_M3_F3_101_272.mp4
# 완료
# ------
# 887
# C_2_5_05_BU_DYA_07-26_18-01-07_CC_RGB_DF1_M2_M2.mp4
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_05_BU_DYA_07-26_18-01-07_CC_RGB_DF1_M2_M2.xml
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_05_BU_DYA_07-26_18-01-07_CC_RGB_DF1_M2_M2.mp4
# return_start
# 81
# return_end
# 180
# return_start
# 341
# return_end
# 458
# start_q [81, 341]
# end_q [180, 458]
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Training/01.원천데이터/TS_02.구매행동_05.반품_1/C_2_5_05_BU_DYA_07-26_18-01-07_CC_RGB_DF1_M2_M2_341_458.mp4

# %%
# Define the file path
file_path = "/home/bigdeal/mnt2/238-1.실내(편의점, 매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CC_RGB_DF1_M4_M4.mp4"
path_parts = file_path.split('/')
print(path_parts[-3])
# Check if "01.원천데이터" is one of the directories in the path
is_source_data_path_parsing = "01.원천데이터" in path_parts

is_source_data_path_parsing

def create_directory_recursively(path):
    try:
        # exist_ok=True 옵션은 해당 경로의 폴더가 이미 존재해도 에러를 발생시키지 않음
        os.makedirs(path, exist_ok=True)
        print(f"'{path}' 디렉토리가 생성되었거나 이미 존재합니다.")
    except PermissionError:
        # 권한 오류 처리
        print(f"권한 오류: '{path}' 디렉토리를 생성할 수 없습니다. 접근 권한을 확인하세요.")
    except Exception as e:
        # 기타 오류 처리
        print(f"오류 발생: {e}")

new_video_dir = os.path.dirname(file_path)
# Create the directory if it doesn't exist
create_directory_recursively(new_video_dir)
# Out:
# 01.원천데이터
# '/home/bigdeal/mnt2/238-1.실내(편의점, 매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.

# %%
with open("/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_02.구매행동_05.반품/C_2_5_14_BU_DYB_10-10_11-39-08_CC_RGB_DF1_F1_F1.xml", 'r', encoding='utf-8') as file:
    xml_string = file.read()
# XML 문자열을 파이썬 딕셔너리로 변환
dict_data = xmltodict.parse(xml_string)
for i in range(len(dict_data['annotations']['track'])):
    if dict_data['annotations']['track'][i]['@label'] in action_list:
        print(dict_data['annotations']['track'][i]['@label'])
        if(isinstance(dict_data['annotations']['track'][i]["box"], list)):
            print(dict_data['annotations']['track'][i]["box"][0]["@frame"])
            if "start" in dict_data['annotations']['track'][i]['@label'] :
                start_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
            if "end" in dict_data['annotations']['track'][i]['@label'] :
                end_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
        else:
            print(dict_data['annotations']['track'][i]["box"]["@frame"])
            if "start" in dict_data['annotations']['track'][i]['@label'] :
                start_q.append(int(dict_data['annotations']['track'][i]["box"]["@frame"]))
            if "end" in dict_data['annotations']['track'][i]['@label'] :
                end_q.append(int(dict_data['annotations']['track'][i]["box"]["@frame"]))
# Out:
# return_start
# {'@frame': '387', '@outside': '1', '@occluded': '0', '@keyframe': '1', '@xtl': '814.54', '@ytl': '493.41', '@xbr': '1023.42', '@ybr': '898.95', '@z_order': '0', 'attribute': [{'@name': 'age group', '#text': 'child'}, {'@name': 'ID', '#text': '2'}, {'@name': 'gender', '#text': 'female'}]}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_545153/2434280105.py in <module>
#       8         print(dict_data['annotations']['track'][i]["box"])
#       9         if "start" in dict_data['annotations']['track'][i]['@label'] :
# ---> 10             start_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
#      11         if "end" in dict_data['annotations']['track'][i]['@label'] :
#      12             end_q.append(int(dict_data['annotations']['track'][i]["box"][0]["@frame"]))
#
# KeyError: 0
