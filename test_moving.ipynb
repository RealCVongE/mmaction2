# %%
import cv2

def get_video_fps(video_path):
    # 비디오 파일 열기
    cap = cv2.VideoCapture(video_path)
    
    # 비디오 파일이 열렸는지 확인
    if not cap.isOpened():
        print("비디오 파일을 열 수 없습니다.")
        return None
    
    # FPS 가져오기
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    # 비디오 파일 닫기
    cap.release()
    
    return fps

# 비디오 파일 경로
video_path = 'C_3_12_1_BU_SMC_08-07_13-30-11_CC_RGB_DF2_M1.mp4'

# FPS 가져오기
fps = get_video_fps(video_path)

if fps is not None:
    print("비디오의 FPS는 {}입니다.".format(fps))
# Out:
# 비디오의 FPS는 3.0입니다.

# %%
import cv2

# 비디오 파일 경로
video_path = 'Sample_buying/Sample/01.원천데이터/02.구매행동/02.선택/C_2_2_10_BU_SYA_09-17_16-18-31_CA_RGB_DF1_F1_F1.mp4'

# 비디오 파일 열기
cap = cv2.VideoCapture(video_path)

# 누적 프레임 번호 변수
frame_number = 179
#마지막 1443
#1443-1080= 363
# 프레임 읽기
ret, frame = cap.read()

# 초기화
current_frame_number = cap.get(cv2.CAP_PROP_POS_FRAMES)  # 현재 프레임 번호
frame_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000  # 현재 프레임의 시간(초)

# 반복
while True:

    # 프레임 정보 표시
    cv2.putText(frame, f"Frame: {current_frame_number}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 2)
    cv2.putText(frame, f"Time: {frame_time:.2f} seconds", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 2)

    # 프레임 보여주기
    cv2.imshow('Frame', frame)

    # 키 입력 처리
    key = cv2.waitKey(1) & 0xFF

    # 왼쪽 화살표 키: 이전 프레임으로 이동
    if key == ord('a'):
        frame_number -= 1
        if frame_number < 0:
            frame_number = 0

    # 오른쪽 화살표 키: 다음 프레임으로 이동
    elif key == ord('d'):
        frame_number += 1

    # 'q' 키: 종료
    elif key == ord('q'):
        break

    # 프레임 설정 및 읽기
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
    ret, frame = cap.read()

    # 프레임 정보 업데이트
    current_frame_number = cap.get(cv2.CAP_PROP_POS_FRAMES)  # 현재 프레임 번호
    frame_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000  # 현재 프레임의 시간(초)

# 비디오 해제
cap.release()

# 종료 메시지
print("종료되었습니다.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 48
#      45     break
#      47 # 프레임 설정 및 읽기
# ---> 48 cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
#      49 ret, frame = cap.read()
#      51 # 프레임 정보 업데이트
#
# KeyboardInterrupt:

# %%
import xmltodict
import json

def convert_xml_to_json(xml_file_path, json_file_path):
    # XML 파일을 열고 읽기
    with open(xml_file_path, 'r', encoding='utf-8') as file:
        xml_string = file.read()
    
    # XML 문자열을 파이썬 딕셔너리로 변환
    dict_data = xmltodict.parse(xml_string)
    
    # 딕셔너리를 JSON 파일로 저장
    with open(json_file_path, 'w', encoding='utf-8') as json_file:
        json_file.write(json.dumps(dict_data, indent=4))

# 사용 예제
xml_file_path = 'Sample_buying/Sample/02.라벨링데이터/02.구매행동/02.선택/C_2_2_10_BU_SYA_09-17_16-18-31_CA_RGB_DF1_F1_F1.xml'
# XML 파일을 열고 읽기
with open(xml_file_path, 'r', encoding='utf-8') as file:
    xml_string = file.read()

# XML 문자열을 파이썬 딕셔너리로 변환
dict_data = xmltodict.parse(xml_string)
print(len(dict_data['annotations']['meta']['task']['labels']['label']))

for i in dict_data['annotations']['meta']['task']['labels']['label']:
    print(i["name"])
print(dict_data['annotations']['track'][0].keys())
print(dict_data['annotations']['track'][0]["box"])
print(dict_data['annotations']['track'][0]['@label'])
print(len(dict_data['annotations']['track'][0]['box']))
print(dict_data['annotations']['track'][0]['box'][0].keys())
# Out:
# 33
# Pelvis
# Center head
# return_start
# return_end
# compare_start
# moving
# compare_end
# Left hip
# Left knee
# Left foot
# Right  hip
# Right knee
# Right foot
# Spine naval
# Spine chest
# Neck base
# Right shoulder
# Right elbow
# Right hand
# Left shoulder
# Left elbow
# Left hand
# select_start
# select_end
# test_start
# test_end
# buying_start
# buying_end
# object_snack
# object_drink
# object_groceries
# object_daily necessity
# object_pay
# dict_keys(['@id', '@label', '@source', 'box'])
# [{'@frame': '179', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1430.29', '@ytl': '321.88', '@xbr': '1465.98', '@ybr': '373.00', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '180', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1429.97', '@ytl': '322.20', '@xbr': '1465.65', '@ybr': '373.32', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '181', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1429.65', '@ytl': '322.52', '@xbr': '1465.33', '@ybr': '373.64', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '182', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1429.33', '@ytl': '322.84', '@xbr': '1465.01', '@ybr': '373.96', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '183', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1424.98', '@ytl': '319.95', '@xbr': '1458.26', '@ybr': '368.68', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '184', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1420.64', '@ytl': '317.06', '@xbr': '1451.50', '@ybr': '363.40', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '185', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1410.52', '@ytl': '317.06', '@xbr': '1441.37', '@ybr': '363.40', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '186', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1400.39', '@ytl': '317.06', '@xbr': '1431.25', '@ybr': '363.40', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '187', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1384.96', '@ytl': '322.36', '@xbr': '1415.81', '@ybr': '368.71', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '188', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1369.52', '@ytl': '327.67', '@xbr': '1400.38', '@ybr': '374.01', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '189', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1352.11', '@ytl': '339.39', '@xbr': '1382.99', '@ybr': '388.06', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '190', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1334.70', '@ytl': '351.11', '@xbr': '1365.60', '@ybr': '402.10', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '191', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1319.95', '@ytl': '373.88', '@xbr': '1350.86', '@ybr': '424.20', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '192', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1305.20', '@ytl': '396.65', '@xbr': '1336.13', '@ybr': '446.30', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '193', '@outside': '0', '@occluded': '0', '@keyframe': '0', '@xtl': '1285.80', '@ytl': '423.78', '@xbr': '1319.72', '@ybr': '471.10', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '194', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1266.40', '@ytl': '450.91', '@xbr': '1303.31', '@ybr': '495.90', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}, {'@frame': '195', '@outside': '0', '@occluded': '0', '@keyframe': '1', '@xtl': '1257.00', '@ytl': '464.30', '@xbr': '1292.59', '@ybr': '508.60', '@z_order': '0', 'attribute': {'@name': 'ID', '#text': '1'}}]
# object_drink
# 17
# dict_keys(['@frame', '@outside', '@occluded', '@keyframe', '@xtl', '@ytl', '@xbr', '@ybr', '@z_order', 'attribute'])

# %%
import os
def create_directory_recursively(path):
    try:
        # exist_ok=True 옵션은 해당 경로의 폴더가 이미 존재해도 에러를 발생시키지 않음
        os.makedirs(path, exist_ok=True)
        print(f"'{path}' 디렉토리가 생성되었거나 이미 존재합니다.")
    except PermissionError:
        # 권한 오류 처리
        print(f"권한 오류: '{path}' 디렉토리를 생성할 수 없습니다. 접근 권한을 확인하세요.")
    except Exception as e:
        # 기타 오류 처리
        print(f"오류 발생: {e}")
def cut_video(video_path, new_path,data_root_path ,start_frame,end_frame):
    # 비디오 캡처 객체 생성
    cap = cv2.VideoCapture(video_path)

    # 총 프레임 수와 FPS 확인
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    # 출력 비디오 설정 (코덱, FPS, 해상도)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    frame_width = int(cap.get(3))
    frame_height = int(cap.get(4))
    new_video_path=video_path.replace(data_root_path, new_path)

    new_video_dir = os.path.dirname(new_video_path)
    # Create the directory if it doesn't exist
    create_directory_recursively(new_video_dir)
    output_path = f'{new_video_path[:-4]}_{start_frame}_{end_frame}.mp4'
    print(output_path)
    
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    current_frame = 0
    while(cap.isOpened()):
        ret, frame = cap.read()
        
        if ret:
            if start_frame <= current_frame <= end_frame:
                out.write(frame)
            
            if current_frame > end_frame:
                break
            
            current_frame += 1
        else:
            break

    # 모든 작업 완료 후 해제
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print("완료")

# %% [markdown]
# # 컷편집 기능

# %%
import os



def count_mp4_files(path):
  """
  주어진 경로와 하위 폴더들을 재귀적으로 탐색하여 mp4 파일 개수를 센다.

  Args:
    path: 탐색을 시작할 경로

  Returns:
    mp4 파일 개수
  """
  mp4_files = []
  mp4_count = 0
  def _count_mp4_files_in_dir(dir_path):
    nonlocal mp4_count
    nonlocal mp4_files
    for file in os.listdir(dir_path):
      full_path = os.path.join(dir_path, file)
      if os.path.isfile(full_path):
        if file.endswith(".mp4"):
          mp4_count += 1
          mp4_files.append(full_path)
      elif os.path.isdir(full_path):
        _count_mp4_files_in_dir(full_path)

  _count_mp4_files_in_dir(path)

  return mp4_count, mp4_files

# 예시 코드
path = "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터"
mp4_count, mp4_files = count_mp4_files(path)

print(f"총 mp4 파일 개수: {mp4_count}")
# print(f"mp4 파일 목록: {mp4_files}")
print(f"mp4 파일 목록: {len(mp4_files)}")
print(f"mp4 파일 목록: {mp4_files[0]}")
# Out:
# 총 mp4 파일 개수: 4304
# mp4 파일 목록: 4304
# mp4 파일 목록: /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CC_RGB_DF1_M4_M4.mp4

# %%
from queue import Queue
# 큐 생성
q = Queue()
# 영상 파일 경로

for j in mp4_files:
    data_root_path= "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터"
    Validation="Validation"
    new_path= "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess"
    # XML 파일을 열고 읽기
    
    video_middle_path="01.원천데이터"
    label_middle_path="02.라벨링데이터"
    if "매장이동" in j:
        continue
    label_path=j.replace(video_middle_path, label_middle_path)
    label_path=label_path.replace("mp4", "xml")
    if "VS" in label_path:
        label_path=label_path.replace("VS", "VL")
    elif "TS" in label_path:
        label_path=label_path.replace("TS", "TL")

    action_list= [
"select_start","select_end",
  "test_start", "test_end",
  "buying_start", "buying_end",
  "return_start", "return_end",
  "compare_start", "compare_end"
]
    print(j)
    with open(label_path, 'r', encoding='utf-8') as file:
        xml_string = file.read()
    # XML 문자열을 파이썬 딕셔너리로 변환
    dict_data = xmltodict.parse(xml_string)
    for i in range(len(dict_data['annotations']['track'])):
        if dict_data['annotations']['track'][i]['@label'] in action_list:
            print(dict_data['annotations']['track'][i]['@label'])
            print(dict_data['annotations']['track'][i]["box"][0]["@frame"])
            q.put(dict_data['annotations']['track'][i]["box"][0]["@frame"])
    while not q.empty():
        start_frame = int(q.get())
        end_frame = int(q.get())
        print("------")
        cut_video( j,new_path,data_root_path,start_frame,end_frame)
# Out:
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CC_RGB_DF1_M4_M4.mp4
# buying_start
# 91
# buying_end
# 194
# buying_start
# 406
# buying_end
# 518
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CC_RGB_DF1_M4_M4_91_194.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CC_RGB_DF1_M4_M4_406_518.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 105
# buying_end
# 214
# buying_start
# 454
# buying_end
# 553
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CD_RGB_DF1_F4_F4_105_214.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CD_RGB_DF1_F4_F4_454_553.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMC_08-20_15-01-34_CA_RGB_DF1_F4.mp4
# buying_start
# 129
# buying_end
# 533
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMC_08-20_15-01-34_CA_RGB_DF1_F4_129_533.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMC_08-20_14-49-08_CA_RGB_DF1_M4.mp4
# buying_start
# 104
# buying_end
# 486
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMC_08-20_14-49-08_CA_RGB_DF1_M4_104_486.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CA_RGB_DF1_M4.mp4
# buying_start
# 89
# buying_end
# 490
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CA_RGB_DF1_M4_89_490.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 87
# buying_end
# 179
# buying_start
# 392
# buying_end
# 512
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CB_RGB_DF1_F4_F4_87_179.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CB_RGB_DF1_F4_F4_392_512.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 90
# buying_end
# 187
# buying_start
# 378
# buying_end
# 487
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CC_RGB_DF1_F4_F4_90_187.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CC_RGB_DF1_F4_F4_378_487.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_DYA_08-24_17-30-11_CB_RGB_DF1_F2_M2.mp4
# buying_start
# 99
# buying_end
# 242
# buying_start
# 420
# buying_end
# 547
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_DYA_08-24_17-30-11_CB_RGB_DF1_F2_M2_99_242.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_DYA_08-24_17-30-11_CB_RGB_DF1_F2_M2_420_547.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 98
# buying_end
# 202
# buying_start
# 394
# buying_end
# 486
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CC_RGB_DF1_F4_F4_98_202.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CC_RGB_DF1_F4_F4_394_486.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CA_RGB_DF1_M4_M4.mp4
# buying_start
# 72
# buying_end
# 234
# buying_start
# 417
# buying_end
# 561
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CA_RGB_DF1_M4_M4_72_234.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CA_RGB_DF1_M4_M4_417_561.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CB_RGB_DF1_M4.mp4
# buying_start
# 112
# buying_end
# 488
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CB_RGB_DF1_M4_112_488.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 57
# buying_end
# 184
# buying_start
# 356
# buying_end
# 515
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CB_RGB_DF1_F4_F4_57_184.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CB_RGB_DF1_F4_F4_356_515.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMC_08-20_14-49-09_CC_RGB_DF1_M4.mp4
# buying_start
# 102
# buying_end
# 484
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMC_08-20_14-49-09_CC_RGB_DF1_M4_102_484.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 90
# buying_end
# 188
# buying_start
# 377
# buying_end
# 487
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CD_RGB_DF1_F4_F4_90_188.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CD_RGB_DF1_F4_F4_377_487.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CD_RGB_DF1_M4_M4.mp4
# buying_start
# 71
# buying_end
# 213
# buying_start
# 392
# buying_end
# 565
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CD_RGB_DF1_M4_M4_71_213.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CD_RGB_DF1_M4_M4_392_565.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-10_CC_RGB_DF1_F4.mp4
# buying_start
# 128
# buying_end
# 500
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-10_CC_RGB_DF1_F4_128_500.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 78
# buying_end
# 230
# buying_start
# 399
# buying_end
# 544
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CD_RGB_DF1_F4_F4_78_230.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CD_RGB_DF1_F4_F4_399_544.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 100
# buying_end
# 202
# buying_start
# 396
# buying_end
# 487
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CB_RGB_DF1_F4_F4_100_202.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CB_RGB_DF1_F4_F4_396_487.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CD_RGB_DF1_M2_M2.mp4
# buying_start
# 71
# buying_end
# 197
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CD_RGB_DF1_M2_M2_71_197.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 90
# buying_end
# 196
# buying_start
# 360
# buying_end
# 446
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CD_RGB_DF1_F4_F4_90_196.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CD_RGB_DF1_F4_F4_360_446.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 88
# buying_end
# 217
# buying_start
# 443
# buying_end
# 553
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CA_RGB_DF1_F4_F4_88_217.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CA_RGB_DF1_F4_F4_443_553.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 91
# buying_end
# 217
# buying_start
# 443
# buying_end
# 553
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CB_RGB_DF1_F4_F4_91_217.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CB_RGB_DF1_F4_F4_443_553.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 54
# buying_end
# 180
# buying_start
# 352
# buying_end
# 512
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CC_RGB_DF1_F4_F4_54_180.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CC_RGB_DF1_F4_F4_352_512.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SMC_08-20_14-46-36_CA_RGB_DF1_M4.mp4
# buying_start
# 68
# buying_end
# 449
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SMC_08-20_14-46-36_CA_RGB_DF1_M4_68_449.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_SMC_08-20_14-56-32_CC_RGB_DF1_F4.mp4
# buying_start
# 98
# buying_end
# 466
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_SMC_08-20_14-56-32_CC_RGB_DF1_F4_98_466.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CD_RGB_DF1_M4_M4.mp4
# buying_start
# 131
# buying_end
# 285
# buying_start
# 465
# buying_end
# 580
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CD_RGB_DF1_M4_M4_131_285.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CD_RGB_DF1_M4_M4_465_580.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SMC_08-20_14-46-36_CB_RGB_DF1_M4.mp4
# buying_start
# 65
# buying_end
# 447
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SMC_08-20_14-46-36_CB_RGB_DF1_M4_65_447.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 65
# buying_end
# 216
# buying_start
# 394
# buying_end
# 563
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CB_RGB_DF1_M4_M4_65_216.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CB_RGB_DF1_M4_M4_394_563.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 80
# buying_end
# 184
# buying_start
# 368
# buying_end
# 459
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CA_RGB_DF1_F4_F4_80_184.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CA_RGB_DF1_F4_F4_368_459.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 85
# buying_end
# 181
# buying_start
# 380
# buying_end
# 512
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CD_RGB_DF1_F4_F4_85_181.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CD_RGB_DF1_F4_F4_380_512.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 97
# buying_end
# 199
# buying_start
# 388
# buying_end
# 487
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CD_RGB_DF1_F4_F4_97_199.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SMB_10-16_18-10-10_CD_RGB_DF1_F4_F4_388_487.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CD_RGB_DF1_F3_F3.mp4
# buying_start
# 52
# buying_end
# 180
# buying_start
# 320
# buying_end
# 433
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CD_RGB_DF1_F3_F3_52_180.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CD_RGB_DF1_F3_F3_320_433.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 108
# buying_end
# 245
# buying_start
# 429
# buying_end
# 561
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CB_RGB_DF1_M4_M4_108_245.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CB_RGB_DF1_M4_M4_429_561.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMC_08-20_14-53-08_CA_RGB_DF1_M4.mp4
# buying_start
# 110
# buying_end
# 485
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMC_08-20_14-53-08_CA_RGB_DF1_M4_110_485.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 78
# buying_end
# 229
# buying_start
# 399
# buying_end
# 544
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CC_RGB_DF1_F4_F4_78_229.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CC_RGB_DF1_F4_F4_399_544.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 90
# buying_end
# 196
# buying_start
# 360
# buying_end
# 446
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CC_RGB_DF1_F4_F4_90_196.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CC_RGB_DF1_F4_F4_360_446.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMC_08-20_14-53-09_CC_RGB_DF1_M4.mp4
# buying_start
# 80
# buying_end
# 479
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMC_08-20_14-53-09_CC_RGB_DF1_M4_80_479.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CD_RGB_DF1_M4_M4.mp4
# buying_start
# 112
# buying_end
# 249
# buying_start
# 442
# buying_end
# 564
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CD_RGB_DF1_M4_M4_112_249.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMB_10-16_18-04-45_CD_RGB_DF1_M4_M4_442_564.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CA_RGB_DF1_M4_M4.mp4
# buying_start
# 130
# buying_end
# 285
# buying_start
# 466
# buying_end
# 580
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CA_RGB_DF1_M4_M4_130_285.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CA_RGB_DF1_M4_M4_466_580.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 130
# buying_end
# 287
# buying_start
# 470
# buying_end
# 581
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CB_RGB_DF1_M4_M4_130_287.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SMB_10-16_18-03-05_CB_RGB_DF1_M4_M4_470_581.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-09_CA_RGB_DF1_F4.mp4
# buying_start
# 136
# buying_end
# 503
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-09_CA_RGB_DF1_F4_136_503.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-40_CB_RGB_DF1_F2_M2.mp4
# buying_start
# 107
# buying_end
# 242
# buying_start
# 370
# buying_end
# 512
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-40_CB_RGB_DF1_F2_M2_107_242.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-40_CB_RGB_DF1_F2_M2_370_512.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 103
# buying_end
# 215
# buying_start
# 453
# buying_end
# 552
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CC_RGB_DF1_F4_F4_103_215.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMB_10-16_18-08-31_CC_RGB_DF1_F4_F4_453_552.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CB_RGB_DF1_F2_F2.mp4
# buying_start
# 98
# buying_end
# 226
# buying_start
# 328
# buying_end
# 478
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CB_RGB_DF1_F2_F2_98_226.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CB_RGB_DF1_F2_F2_328_478.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CC_RGB_DF1_M4.mp4
# buying_start
# 112
# buying_end
# 489
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SMC_08-20_14-51-01_CC_RGB_DF1_M4_112_489.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 72
# buying_end
# 213
# buying_start
# 392
# buying_end
# 567
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CB_RGB_DF1_M4_M4_72_213.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CB_RGB_DF1_M4_M4_392_567.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 83
# buying_end
# 232
# buying_start
# 402
# buying_end
# 544
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CA_RGB_DF1_F4_F4_83_232.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_55_BU_SYB_10-16_18-20-51_CA_RGB_DF1_F4_F4_402_544.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CA_RGB_DF1_F2_F2.mp4
# buying_start
# 102
# buying_end
# 230
# buying_start
# 333
# buying_end
# 482
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CA_RGB_DF1_F2_F2_102_230.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYA_08-24_17-26-08_CA_RGB_DF1_F2_F2_333_482.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-41_CC_RGB_DF1_F2_M2.mp4
# buying_start
# 107
# buying_end
# 242
# buying_start
# 370
# buying_end
# 511
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-41_CC_RGB_DF1_F2_M2_107_242.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYA_08-24_17-32-41_CC_RGB_DF1_F2_M2_370_511.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMC_08-20_15-03-31_CA_RGB_DF1_F4.mp4
# buying_start
# 114
# buying_end
# 509
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMC_08-20_15-03-31_CA_RGB_DF1_F4_114_509.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CC_RGB_DF1_M2_M2.mp4
# buying_start
# 72
# buying_end
# 197
# buying_start
# 392
# buying_end
# 499
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CC_RGB_DF1_M2_M2_72_197.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_DYB_10-20_09-22-28_CC_RGB_DF1_M2_M2_392_499.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-10_CB_RGB_DF1_F4.mp4
# buying_start
# 131
# buying_end
# 500
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SMC_08-20_14-59-10_CB_RGB_DF1_F4_131_500.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 86
# buying_end
# 190
# buying_start
# 375
# buying_end
# 467
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CD_RGB_DF1_F4_F4_86_190.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CD_RGB_DF1_F4_F4_375_467.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CC_RGB_DF1_M4_M4.mp4
# buying_start
# 69
# buying_end
# 211
# buying_start
# 395
# buying_end
# 567
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CC_RGB_DF1_M4_M4_69_211.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CC_RGB_DF1_M4_M4_395_567.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 81
# buying_end
# 178
# buying_start
# 367
# buying_end
# 477
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CB_RGB_DF1_F4_F4_81_178.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_DYB_10-20_15-41-32_CB_RGB_DF1_F4_F4_367_477.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CC_RGB_DF1_F3_F3.mp4
# buying_start
# 52
# buying_end
# 180
# buying_start
# 320
# buying_end
# 433
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CC_RGB_DF1_F3_F3_52_180.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_49_BU_SYB_10-16_14-06-43_CC_RGB_DF1_F3_F3_320_433.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMC_08-20_15-03-31_CB_RGB_DF1_F4.mp4
# buying_start
# 110
# buying_end
# 506
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMC_08-20_15-03-31_CB_RGB_DF1_F4_110_506.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CA_RGB_DF1_M4_M4.mp4
# buying_start
# 72
# buying_end
# 213
# buying_start
# 392
# buying_end
# 567
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CA_RGB_DF1_M4_M4_72_213.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_51_BU_SYB_10-16_18-16-32_CA_RGB_DF1_M4_M4_392_567.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CB_RGB_DF1_F4_F4.mp4
# buying_start
# 72
# buying_end
# 172
# buying_start
# 415
# buying_end
# 511
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CB_RGB_DF1_F4_F4_72_172.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CB_RGB_DF1_F4_F4_415_511.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 84
# buying_end
# 197
# buying_start
# 369
# buying_end
# 463
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CA_RGB_DF1_F4_F4_84_197.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_53_BU_DYB_10-20_15-42-46_CA_RGB_DF1_F4_F4_369_463.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CA_RGB_DF1_M4_M4.mp4
# buying_start
# 60
# buying_end
# 215
# buying_start
# 394
# buying_end
# 563
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CA_RGB_DF1_M4_M4_60_215.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_SYB_10-16_18-15-05_CA_RGB_DF1_M4_M4_394_563.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CA_RGB_DF1_F4_F4.mp4
# buying_start
# 73
# buying_end
# 172
# buying_start
# 417
# buying_end
# 510
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CA_RGB_DF1_F4_F4_73_172.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_DYB_10-20_15-44-16_CA_RGB_DF1_F4_F4_417_510.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 86
# buying_end
# 190
# buying_start
# 375
# buying_end
# 466
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CC_RGB_DF1_F4_F4_86_190.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_50_BU_DYB_10-20_15-38-31_CC_RGB_DF1_F4_F4_375_466.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CC_RGB_DF1_F4_F4.mp4
# buying_start
# 85
# buying_end
# 181
# buying_start
# 380
# buying_end
# 512
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CC_RGB_DF1_F4_F4_85_181.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_56_BU_SMB_10-16_18-11-42_CC_RGB_DF1_F4_F4_380_512.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CD_RGB_DF1_M4_M4.mp4
# buying_start
# 70
# buying_end
# 235
# buying_start
# 416
# buying_end
# 559
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CD_RGB_DF1_M4_M4_70_235.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CD_RGB_DF1_M4_M4_416_559.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CB_RGB_DF1_M4_M4.mp4
# buying_start
# 93
# buying_end
# 202
# buying_start
# 408
# buying_end
# 521
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CB_RGB_DF1_M4_M4_93_202.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CB_RGB_DF1_M4_M4_408_521.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CD_RGB_DF1_F4_F4.mp4
# buying_start
# 55
# buying_end
# 180
# buying_start
# 353
# buying_end
# 511
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CD_RGB_DF1_F4_F4_55_180.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_54_BU_SYB_10-16_18-19-27_CD_RGB_DF1_F4_F4_353_511.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CC_RGB_DF1_M4_M4.mp4
# buying_start
# 65
# buying_end
# 235
# buying_start
# 415
# buying_end
# 559
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SYB_10-16_18-17-48_CC_RGB_DF1_M4_M4_65_235.mp4
# 완료
# ------
# ...
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_107_BU_DYB_10-20_15-51-37_CB_RGB_DF1_M4_M4.mp4
# return_start
# 95
# return_end
# 209
# return_start
# 426
# return_end
# 536
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_107_BU_DYB_10-20_15-51-37_CB_RGB_DF1_M4_M4_95_209.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_107_BU_DYB_10-20_15-51-37_CB_RGB_DF1_M4_M4_426_536.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_95_BU_SYB_10-16_18-44-40_CB_RGB_DF1_M4_M4.mp4
# return_start
# 86
# return_end
# 206
# return_start
# 389
# return_end
# 502
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_95_BU_SYB_10-16_18-44-40_CB_RGB_DF1_M4_M4_86_206.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_95_BU_SYB_10-16_18-44-40_CB_RGB_DF1_M4_M4_389_502.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_108_BU_DYB_10-20_15-53-27_CC_RGB_DF1_M4_M4.mp4
# return_start
# 98
# return_end
# 199
# return_start
# 402
# return_end
# 498
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_108_BU_DYB_10-20_15-53-27_CC_RGB_DF1_M4_M4_98_199.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_108_BU_DYB_10-20_15-53-27_CC_RGB_DF1_M4_M4_402_498.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_DYB_10-23_13-52-56_CD_RGB_DF1_F3_F3.mp4
# return_start
# 91
# return_end
# 218
# return_start
# 413
# return_end
# 544
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_DYB_10-23_13-52-56_CD_RGB_DF1_F3_F3_91_218.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_DYB_10-23_13-52-56_CD_RGB_DF1_F3_F3_413_544.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_98_BU_SYB_10-16_18-49-43_CB_RGB_DF1_F4_F4.mp4
# return_start
# 84
# return_end
# 203
# return_start
# 393
# return_end
# 522
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_98_BU_SYB_10-16_18-49-43_CB_RGB_DF1_F4_F4_84_203.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_98_BU_SYB_10-16_18-49-43_CB_RGB_DF1_F4_F4_393_522.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_DYB_10-23_13-52-56_CA_RGB_DF1_F3_F3.mp4
# return_start
# 92
# return_end
# 216
# return_start
# 414
# return_end
# 542
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_DYB_10-23_13-52-56_CA_RGB_DF1_F3_F3_92_216.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_DYB_10-23_13-52-56_CA_RGB_DF1_F3_F3_414_542.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_104_BU_DYB_10-20_15-47-19_CB_RGB_DF1_M4_M4.mp4
# return_start
# 80
# return_end
# 184
# return_start
# 439
# return_end
# 526
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_104_BU_DYB_10-20_15-47-19_CB_RGB_DF1_M4_M4_80_184.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_104_BU_DYB_10-20_15-47-19_CB_RGB_DF1_M4_M4_439_526.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_DYB_10-23_13-52-56_CC_RGB_DF1_F3_F3.mp4
# return_start
# 91
# return_end
# 222
# return_start
# 414
# return_end
# 545
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_DYB_10-23_13-52-56_CC_RGB_DF1_F3_F3_91_222.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_DYB_10-23_13-52-56_CC_RGB_DF1_F3_F3_414_545.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_DYB_10-23_13-56-12_CC_RGB_DF1_F3_F3.mp4
# return_start
# 93
# return_end
# 216
# return_start
# 455
# return_end
# 538
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_DYB_10-23_13-56-12_CC_RGB_DF1_F3_F3_93_216.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_DYB_10-23_13-56-12_CC_RGB_DF1_F3_F3_455_538.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_101_BU_SYB_10-16_18-59-43_CA_RGB_DF1_F4_F4.mp4
# return_start
# 63
# return_end
# 173
# return_start
# 335
# return_end
# 449
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_101_BU_SYB_10-16_18-59-43_CA_RGB_DF1_F4_F4_63_173.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_101_BU_SYB_10-16_18-59-43_CA_RGB_DF1_F4_F4_335_449.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_104_BU_DYB_10-20_15-47-19_CD_RGB_DF1_M4_M4.mp4
# return_start
# 89
# return_end
# 193
# return_start
# 448
# return_end
# 535
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_104_BU_DYB_10-20_15-47-19_CD_RGB_DF1_M4_M4_89_193.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_104_BU_DYB_10-20_15-47-19_CD_RGB_DF1_M4_M4_448_535.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_DYB_10-23_13-56-12_CD_RGB_DF1_F3_F3.mp4
# return_start
# 93
# return_end
# 217
# return_start
# 454
# return_end
# 540
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_DYB_10-23_13-56-12_CD_RGB_DF1_F3_F3_93_217.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_DYB_10-23_13-56-12_CD_RGB_DF1_F3_F3_454_540.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_98_BU_DYB_10-23_13-54-21_CC_RGB_DF1_F3_F3.mp4
# return_start
# 89
# return_end
# 220
# return_start
# 418
# return_end
# 549
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_98_BU_DYB_10-23_13-54-21_CC_RGB_DF1_F3_F3_89_220.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_98_BU_DYB_10-23_13-54-21_CC_RGB_DF1_F3_F3_418_549.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_SYA_09-16_15-01-55_CA_RGB_DF1_M4_M4.mp4
# return_start
# 68
# return_end
# 199
# return_start
# 387
# return_end
# 515
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_SYA_09-16_15-01-55_CA_RGB_DF1_M4_M4_68_199.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_97_BU_SYA_09-16_15-01-55_CA_RGB_DF1_M4_M4_387_515.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_101_BU_SYA_09-16_15-15-27_CB_RGB_DF1_F4_F4.mp4
# return_start
# 77
# return_end
# 198
# return_start
# 395
# return_end
# 522
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_101_BU_SYA_09-16_15-15-27_CB_RGB_DF1_F4_F4_77_198.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_101_BU_SYA_09-16_15-15-27_CB_RGB_DF1_F4_F4_395_522.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_DYB_10-23_13-56-12_CB_RGB_DF1_F3_F3.mp4
# return_start
# 92
# return_end
# 216
# return_start
# 454
# return_end
# 538
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_DYB_10-23_13-56-12_CB_RGB_DF1_F3_F3_92_216.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_DYB_10-23_13-56-12_CB_RGB_DF1_F3_F3_454_538.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_SYB_10-16_18-56-56_CC_RGB_DF1_F4_F4.mp4
# return_start
# 75
# return_end
# 192
# return_start
# 360
# return_end
# 486
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_SYB_10-16_18-56-56_CC_RGB_DF1_F4_F4_75_192.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_99_BU_SYB_10-16_18-56-56_CC_RGB_DF1_F4_F4_360_486.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_101_BU_SYA_09-16_15-15-27_CA_RGB_DF1_F4_F4.mp4
# return_start
# 70
# return_end
# 202
# return_start
# 400
# return_end
# 536
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_101_BU_SYA_09-16_15-15-27_CA_RGB_DF1_F4_F4_70_202.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_101_BU_SYA_09-16_15-15-27_CA_RGB_DF1_F4_F4_400_536.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_98_BU_SYA_09-16_15-10-51_CA_RGB_DF1_F4_F4.mp4
# return_start
# 73
# return_end
# 203
# return_start
# 402
# return_end
# 540
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_98_BU_SYA_09-16_15-10-51_CA_RGB_DF1_F4_F4_73_203.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_98_BU_SYA_09-16_15-10-51_CA_RGB_DF1_F4_F4_402_540.mp4
# 완료
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_113_BU_DYB_10-20_16-00-20_CA_RGB_DF1_M4_M4.mp4
# return_end
# 528
# return_start
# 97
# return_end
# 210
# return_start
# 417
# return_end
# 528
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_113_BU_DYB_10-20_16-00-20_CA_RGB_DF1_M4_M4_528_97.mp4
# 완료
# ------
# '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품' 디렉토리가 생성되었거나 이미 존재합니다.
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_05.반품/C_2_5_113_BU_DYB_10-20_16-00-20_CA_RGB_DF1_M4_M4_210_417.mp4

# %%
from queue import Queue
# 큐 생성
q = Queue()
# 영상 파일 경로
mp4_files= ["/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_01.매장이동_01.매장이동_1/C_1_1_1_BU_DYA_08-13_12-11-02_CA_DF1_M1_M1.mp4"]
for j in mp4_files:
    data_root_path= "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터"
    Validation="Validation"
    new_path= "/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/PreProcess"
    # XML 파일을 열고 읽기
    
    video_middle_path="01.원천데이터"
    label_middle_path="02.라벨링데이터"
    if not "매장이동" in j:
        continue
    label_path=j.replace(video_middle_path, label_middle_path)
    label_path=label_path.replace("mp4", "xml")
    if "VS" in label_path:
        label_path=label_path.replace("VS", "VL")
    elif "TS" in label_path:
        label_path=label_path.replace("TS", "TL")

    action_list= [
"moving"
]
    print(j)
    with open(label_path, 'r', encoding='utf-8') as file:
        xml_string = file.read()
    # XML 문자열을 파이썬 딕셔너리로 변환
    dict_data = xmltodict.parse(xml_string)
    for i in range(len(dict_data['annotations']['track'])):
        if dict_data['annotations']['track'][i]['@label'] in action_list:
            print(dict_data['annotations']['track'][i]['@label'])
            print(dict_data['annotations']['track'][i]["box"][0]["@frame"])
            q.put(dict_data['annotations']['track'][i]["box"][0]["@frame"])
    while not q.empty():
        start_frame = int(q.get())
        end_frame = int(q.get())
        print("------")
        # cut_video( j,new_path,data_root_path,start_frame,end_frame)
# Out:
# /home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/01.원천데이터/TS_01.매장이동_01.매장이동_1/C_1_1_1_BU_DYA_08-13_12-11-02_CA_DF1_M1_M1.mp4
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_610477/1613671800.py in <module>
#      25 ]
#      26     print(j)
# ---> 27     with open(label_path, 'r', encoding='utf-8') as file:
#      28         xml_string = file.read()
#      29     # XML 문자열을 파이썬 딕셔너리로 변환
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Training/02.라벨링데이터/TL_01.매장이동_01.매장이동_1/C_1_1_1_BU_DYA_08-13_12-11-02_CA_DF1_M1_M1.xml'

# %%
import xmltodict
with open("/home/bigdeal/mnt2/238-1.실내(편의점,_매장)_사람_구매행동_데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_01.매장이동_01.매장이동/C_1_1_85_BU_DYB_10-19_13-12-56_CB_DF1_M4_M4.xml", 'r', encoding='utf-8') as file:
    xml_string = file.read()
# XML 문자열을 파이썬 딕셔너리로 변환
dict_data = xmltodict.parse(xml_string)
for i in range(len(dict_data['annotations']['track'])):
    if dict_data['annotations']['track'][i]['@label'] in action_list:
        print(dict_data['annotations']['track'][i]['@label'])
        moving_start=int(dict_data['annotations']['track'][i]["box"][0]["@frame"])
        moving_end=int(dict_data['annotations']['track'][i]["box"][0]["@frame"])+len(dict_data['annotations']['track'][i]["box"])-1
        print(moving_start)
        print(moving_end)
# Out:
# moving
# 36
# 169
# moving
# 272
# 329
# moving
# 354
# 516
# moving
# 556
# 629
# moving
# 758
# 900

# %%
# Define the file path
file_path = "/home/bigdeal/mnt2/238-1.실내(편의점, 매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매/C_2_4_52_BU_SMB_10-16_18-06-15_CC_RGB_DF1_M4_M4.mp4"
path_parts = file_path.split('/')
print(path_parts[-3])
# Check if "01.원천데이터" is one of the directories in the path
is_source_data_path_parsing = "01.원천데이터" in path_parts

is_source_data_path_parsing

def create_directory_recursively(path):
    try:
        # exist_ok=True 옵션은 해당 경로의 폴더가 이미 존재해도 에러를 발생시키지 않음
        os.makedirs(path, exist_ok=True)
        print(f"'{path}' 디렉토리가 생성되었거나 이미 존재합니다.")
    except PermissionError:
        # 권한 오류 처리
        print(f"권한 오류: '{path}' 디렉토리를 생성할 수 없습니다. 접근 권한을 확인하세요.")
    except Exception as e:
        # 기타 오류 처리
        print(f"오류 발생: {e}")

new_video_dir = os.path.dirname(file_path)
# Create the directory if it doesn't exist
create_directory_recursively(new_video_dir)
# Out:
# 01.원천데이터
# '/home/bigdeal/mnt2/238-1.실내(편의점, 매장)_사람_구매행동_데이터/PreProcess/Validation/01.원천데이터/VS_02.구매행동_04.구매' 디렉토리가 생성되었거나 이미 존재합니다.
