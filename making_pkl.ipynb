# %%
# !python tools/data/skeleton/ntu_pose_extraction_chg.py softlink_retail/01-1.정식개방데이터/Training/04.rename데이터/TS_03.이상행동_07.전도/C_3_7_1_BU_SMA_08-28_13-18-49_CC_RGB_DF2_M1A001.mp4 softlink_retail/01-1.정식개방데이터/Training/03.pkl데이터/TS_03.이상행동_07.전도/C_3_7_1_BU_SMA_08-28_13-18-49_CC_RGB_DF2_M1A001.pkl
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# Performing Human Detection for each frame
# [                                                  ] 0/180, elapsed: 0s, ETA:03/18 11:33:07 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 03/18 11:33:07 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
#
# [                                 ] 1/180, 1.1 task/s, elapsed: 1s, ETA:   168s
# [                                 ] 2/180, 1.8 task/s, elapsed: 1s, ETA:    98s
# [                                 ] 3/180, 2.4 task/s, elapsed: 1s, ETA:    73s
# [                                 ] 4/180, 2.9 task/s, elapsed: 1s, ETA:    60s
# ...

# %%
# !python tools/data/skeleton/ntu_pose_extraction_chg.py softlink_retail/01-1.정식개방데이터/Training/04.rename데이터/TS_03.이상행동_07.전도/C_3_7_1_BU_SMB_08-28_15-37-05_CA_RGB_DF2_M1A001.mp4 softlink_retail/01-1.정식개방데이터/Training/03.pkl데이터/TS_03.이상행동_07.전도/C_3_7_1_BU_SMB_08-28_15-37-05_CA_RGB_DF2_M1A001.pkl
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# Traceback (most recent call last):
#   File "tools/data/skeleton/ntu_pose_extraction_chg.py", line 305, in <module>
#     anno = ntu_pose_extraction(args.video, args.skip_postproc)
#   File "tools/data/skeleton/ntu_pose_extraction_chg.py", line 269, in ntu_pose_extraction
#     det_results = ntu_det_postproc(vid, det_results)
#   File "tools/data/skeleton/ntu_pose_extraction_chg.py", line 200, in ntu_det_postproc
#     label = int(vid.split('/')[-1].split('A')[1][:3])
# ValueError: invalid literal for int() with base 10: '_RG'
# Performing Human Detection for each frame
# ...

# %%
# !python tools/data/skeleton/ntu_pose_extraction_yyw.py softlink_retail/01-1.정식개방데이터/Training/01.원천데이터/TS_03.이상행동_07.전도/C_3_7_1_BU_DYA_07-31_15-15-25_CA_RGB_DF2_M1.mp4 softlink_retail/01-1.정식개방데이터/Training/01.원천데이터/TS_03.이상행동_07.전도/C_3_7_1_BU_DYA_07-31_15-15-25_CA_RGB_DF2_M1.pkl
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# Performing Human Detection for each frame
# [                                                  ] 0/180, elapsed: 0s, ETA:03/18 15:52:22 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 03/18 15:52:22 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
#
# [                                 ] 1/180, 1.1 task/s, elapsed: 1s, ETA:   159s
# [                                 ] 2/180, 2.0 task/s, elapsed: 1s, ETA:    91s
# [                                 ] 3/180, 2.6 task/s, elapsed: 1s, ETA:    68s
# [                                 ] 4/180, 3.1 task/s, elapsed: 1s, ETA:    57s
# ...

# %% [markdown]
# softlink_retail/01-1.정식개방데이터/Training/01.원천데이터/TS_03.이상행동_07.전도/C_3_7_42_BU_SMC_10-16_10-27-42_CA_RGB_DF2_F1.mp4

# %%
# !python tools/data/skeleton/ntu_pose_extraction_yyw.py softlink_retail/01-1.정식개방데이터/Training/01.원천데이터/TS_03.이상행동_07.전도/C_3_7_42_BU_SMC_10-16_10-27-42_CA_RGB_DF2_F1.mp4 softlink_retail/01-1.정식개방데이터/Training/01.원천데이터/TS_03.이상행동_07.전도/C_3_7_42_BU_SMC_10-16_10-27-42_CA_RGB_DF2_F1.pkl
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# Performing Human Detection for each frame
# [                                                  ] 0/180, elapsed: 0s, ETA:03/18 17:07:14 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 03/18 17:07:14 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
#
# [                                 ] 1/180, 0.8 task/s, elapsed: 1s, ETA:   232s
# [                                 ] 2/180, 1.4 task/s, elapsed: 1s, ETA:   131s
# [                                 ] 3/180, 1.8 task/s, elapsed: 2s, ETA:    96s
# [                                 ] 4/180, 2.2 task/s, elapsed: 2s, ETA:    79s
# ...
